# %% [markdown]
# # AI-Powered Security Scanner Agent with Gemini - Vertex AI Workbench
#
# This notebook demonstrates how to build an **AI-powered** security scanning agent using:
# - **Gemini API** from Google AI Studio (free tier)
# - **GCP Agent Development Kit** for orchestration
# - **Semgrep** for security scanning
# - **Vertex AI** for deployment
#
# ## What Makes This AI-Powered?
# - Gemini analyzes scan results and provides intelligent insights
# - AI explains vulnerabilities in natural language
# - Prioritizes fixes based on context
# - Suggests remediation code
# - Answers follow-up questions about security issues

# %% [markdown]
# ## Cell 1: Install Dependencies

# %%
# Install required packages
# !pip install -q --upgrade pip
# !pip install -q google-cloud-aiplatform[reasoningengine]
# !pip install -q google-genai
# !pip install -q semgrep
# !pip install -q gitpython
# !pip install -q flask

print("✅ All dependencies installed successfully!")
# Out:
# ✅ All dependencies installed successfully!

# %% [markdown]
# ## Cell 2: Configure API Keys and GCP Settings
#
# ⚠️ **IMPORTANT**: Get your Gemini API key from [Google AI Studio](https://aistudio.google.com/app/apikey)

# %%
import os

# ================== CONFIGURE THESE ===================
# Get your free Gemini API key from: https://aistudio.google.com/app/apikey
GEMINI_API_KEY = "<enter API Key>"  # Replace with your API key

# GCP Configuration
PROJECT_ID = "<enter project ID>"  # Replace with your GCP project ID
LOCATION = "<Enter Location>"  # Or your preferred region
STAGING_BUCKET = "gs://<bucket-name>"  # Replace with your GCS bucket
# =====================================================

# Set environment variables
os.environ["GEMINI_API_KEY"] = GEMINI_API_KEY
os.environ["GCP_PROJECT_ID"] = PROJECT_ID
os.environ["GCP_LOCATION"] = LOCATION
os.environ["GCS_STAGING_BUCKET"] = STAGING_BUCKET

print(f"✅ Configuration set:")
print(f"   Gemini API Key: {'*' * 20}{GEMINI_API_KEY[-4:]}")
print(f"   Project ID: {PROJECT_ID}")
print(f"   Location: {LOCATION}")
print(f"   Staging Bucket: {STAGING_BUCKET}")
# Out:
# ✅ Configuration set:
#    Gemini API Key: ********************LGzQ
#    Project ID: steam-aria-479903-s9
#    Location: us-central1
#    Staging Bucket: gs://dataset-bucket-imran

# %% [markdown]
# ## Cell 3: Test Gemini API Connection

# %%
from google import genai
from google.genai import types

# Configure Gemini client
client = genai.Client(api_key=GEMINI_API_KEY)

# First, let's list available models to see what's supported
print("🔍 Checking available models...\n")
try:
    models = client.models.list()
    print("Available models:")
    for model in models:
        print(f"  - {model.name}")
    print()
except Exception as e:
    print(f"Could not list models: {e}\n")

# Try with gemini-2.0-flash-exp (latest experimental model)
try:
    response = client.models.generate_content(
        model='models/gemini-2.0-flash-exp',
        contents="Say 'Hello! I'm ready to analyze security vulnerabilities!'"
    )
    print("🤖 Gemini Response:")
    print(response.text)
    print("\n✅ Gemini API is working correctly!")
except Exception as e:
    print(f"❌ Error with gemini-2.0-flash-exp: {e}")
    
    # Fallback to gemini-1.5-pro
    try:
        print("\nTrying gemini-1.5-pro...")
        response = client.models.generate_content(
            model='models/gemini-1.5-pro',
            contents="Say 'Hello! I'm ready to analyze security vulnerabilities!'"
        )
        print("🤖 Gemini Response:")
        print(response.text)
        print("\n✅ Gemini API is working correctly!")
    except Exception as e2:
        print(f"❌ Error with gemini-1.5-pro: {e2}")
# Out:
# 🔍 Checking available models...
#
# Available models:
#   - models/embedding-gecko-001
#   - models/gemini-2.5-flash
#   - models/gemini-2.5-pro
#   - models/gemini-2.0-flash-exp
#   - models/gemini-2.0-flash
#   - models/gemini-2.0-flash-001
#   - models/gemini-2.0-flash-exp-image-generation
#   - models/gemini-2.0-flash-lite-001
#   - models/gemini-2.0-flash-lite
#   - models/gemini-2.0-flash-lite-preview-02-05
#   - models/gemini-2.0-flash-lite-preview
#   - models/gemini-exp-1206
#   - models/gemini-2.5-flash-preview-tts
#   - models/gemini-2.5-pro-preview-tts
#   - models/gemma-3-1b-it
#   - models/gemma-3-4b-it
#   - models/gemma-3-12b-it
#   - models/gemma-3-27b-it
#   - models/gemma-3n-e4b-it
#   - models/gemma-3n-e2b-it
#   - models/gemini-flash-latest
#   - models/gemini-flash-lite-latest
#   - models/gemini-pro-latest
#   - models/gemini-2.5-flash-lite
#   - models/gemini-2.5-flash-image-preview
#   - models/gemini-2.5-flash-image
#   - models/gemini-2.5-flash-preview-09-2025
#   - models/gemini-2.5-flash-lite-preview-09-2025
#   - models/gemini-3-pro-preview
#   - models/gemini-3-flash-preview
#   - models/gemini-3-pro-image-preview
#   - models/nano-banana-pro-preview
#   - models/gemini-robotics-er-1.5-preview
#   - models/gemini-2.5-computer-use-preview-10-2025
#   - models/deep-research-pro-preview-12-2025
#   - models/embedding-001
#   - models/text-embedding-004
#   - models/gemini-embedding-exp-03-07
#   - models/gemini-embedding-exp
#   - models/gemini-embedding-001
#   - models/aqa
#   - models/imagen-4.0-generate-preview-06-06
#   - models/imagen-4.0-ultra-generate-preview-06-06
#   - models/imagen-4.0-generate-001
#   - models/imagen-4.0-ultra-generate-001
#   - models/imagen-4.0-fast-generate-001
#   - models/veo-2.0-generate-001
#   - models/veo-3.0-generate-001
#   - models/veo-3.0-fast-generate-001
#   - models/veo-3.1-generate-preview
#   - models/veo-3.1-fast-generate-preview
#   - models/gemini-2.5-flash-native-audio-latest
#   - models/gemini-2.5-flash-native-audio-preview-09-2025
#   - models/gemini-2.5-flash-native-audio-preview-12-2025
#
# 🤖 Gemini Response:
# Hello! I'm ready to analyze security vulnerabilities!
#
#
# ✅ Gemini API is working correctly!

# %% [markdown]
# ## Cell 4: Create Sample Vulnerable Application

# %%
# %%writefile sample_app.py
"""
Sample vulnerable Python application for security scanning demo
This intentionally contains security vulnerabilities for demonstration purposes
"""

import os
import pickle
import subprocess
import sqlite3
from flask import Flask, request, render_template_string

app = Flask(__name__)

# Vulnerability 1: Hardcoded credentials
DATABASE_PASSWORD = "admin123"
API_KEY = "sk-1234567890abcdef"

# Vulnerability 2: SQL Injection
@app.route('/user')
def get_user():
    user_id = request.args.get('id')
    conn = sqlite3.connect('users.db')
    cursor = conn.cursor()
    # Vulnerable to SQL injection
    query = f"SELECT * FROM users WHERE id = {user_id}"
    cursor.execute(query)
    result = cursor.fetchone()
    return str(result)

# Vulnerability 3: Command Injection
@app.route('/ping')
def ping():
    host = request.args.get('host')
    # Vulnerable to command injection
    result = os.system(f"ping -c 1 {host}")
    return f"Ping result: {result}"

# Vulnerability 4: Insecure Deserialization
@app.route('/load_data', methods=['POST'])
def load_data():
    data = request.data
    # Vulnerable to insecure deserialization
    obj = pickle.loads(data)
    return str(obj)

# Vulnerability 5: Server-Side Template Injection (SSTI)
@app.route('/hello')
def hello():
    name = request.args.get('name', 'Guest')
    # Vulnerable to SSTI
    template = f"<h1>Hello {name}!</h1>"
    return render_template_string(template)

# Vulnerability 6: Path Traversal
@app.route('/read_file')
def read_file():
    filename = request.args.get('file')
    # Vulnerable to path traversal
    with open(f'/var/data/{filename}', 'r') as f:
        return f.read()

# Vulnerability 7: Weak Cryptography
def encrypt_data(data):
    import hashlib
    # Using MD5 (weak hash)
    return hashlib.md5(data.encode()).hexdigest()

# Vulnerability 8: Debug mode in production
if __name__ == '__main__':
    app.run(debug=True, host='0.0.0.0')

print("✅ Sample vulnerable application created!")
# Out:
# Writing sample_app.py

# %% [markdown]
# ## Cell 5: Define AI-Powered Security Scanner Agent
#
# This agent uses Gemini to:
# - Analyze scan results intelligently
# - Explain vulnerabilities in plain language
# - Prioritize fixes
# - Suggest remediation code

# %%
import os
import subprocess
import tempfile
import shutil
from typing import Dict, List, Any
import json
from google import genai
from google.genai import types

class AISecurityScannerAgent:
    """
    AI-Powered Security Scanner Agent that uses Gemini for intelligent analysis
    """
    
    def __init__(self, gemini_api_key: str):
        """Initialize the AI Security Scanner Agent"""
        self.gemini_api_key = gemini_api_key
        self.client = genai.Client(api_key=gemini_api_key)
        self.model_name = 'models/gemini-2.0-flash-exp'  # Updated to 2.0 flash
        self.semgrep_installed = self._check_semgrep()
        
    def _check_semgrep(self) -> bool:
        """Check if Semgrep is installed"""
        try:
            subprocess.run(
                ["semgrep", "--version"],
                check=True,
                capture_output=True,
                text=True
            )
            return True
        except (subprocess.CalledProcessError, FileNotFoundError):
            print("Semgrep not found. Installing...")
            self._install_semgrep()
            return True
    
    def _install_semgrep(self):
        """Install Semgrep"""
        try:
            subprocess.run(
                ["pip", "install", "semgrep"],
                check=True
            )
            print("Semgrep installed successfully")
        except subprocess.CalledProcessError as e:
            raise RuntimeError(f"Failed to install Semgrep: {e}")
    
    def clone_repository(self, repo_url: str, temp_dir: str) -> str:
        """
        Clone a GitHub repository to a temporary directory
        
        Args:
            repo_url: GitHub repository URL
            temp_dir: Temporary directory path
            
        Returns:
            Path to the cloned repository
        """
        try:
            print(f"Cloning repository: {repo_url}")
            subprocess.run(
                ["git", "clone", repo_url, temp_dir],
                check=True,
                capture_output=True,
                text=True
            )
            print(f"Repository cloned to: {temp_dir}")
            return temp_dir
        except subprocess.CalledProcessError as e:
            raise RuntimeError(f"Failed to clone repository: {e.stderr}")
    
    def run_semgrep_scan(self, repo_path: str, rules: str = "auto") -> Dict[str, Any]:
        """
        Run Semgrep scan on the repository
        
        Args:
            repo_path: Path to the repository
            rules: Semgrep rules to use (default: "auto")
            
        Returns:
            Dictionary containing scan results
        """
        try:
            print(f"Running Semgrep scan on: {repo_path}")
            
            result = subprocess.run(
                [
                    "semgrep",
                    "--config", rules,
                    "--json",
                    "--quiet",
                    repo_path
                ],
                capture_output=True,
                text=True,
                timeout=300
            )
            
            scan_results = json.loads(result.stdout)
            
            print(f"Scan completed. Found {len(scan_results.get('results', []))} issues")
            return scan_results
            
        except subprocess.TimeoutExpired:
            raise RuntimeError("Semgrep scan timed out")
        except subprocess.CalledProcessError as e:
            raise RuntimeError(f"Semgrep scan failed: {e.stderr}")
        except json.JSONDecodeError as e:
            raise RuntimeError(f"Failed to parse Semgrep output: {e}")
    
    def ai_analyze_vulnerability(self, issue: Dict[str, Any]) -> str:
        """
        Use Gemini AI to analyze a specific vulnerability
        
        Args:
            issue: Single vulnerability from Semgrep results
            
        Returns:
            AI-generated analysis and recommendations
        """
        prompt = f"""
You are a security expert analyzing code vulnerabilities. Analyze this security issue:

**Vulnerability Type**: {issue.get('check_id', 'Unknown')}
**Severity**: {issue.get('extra', {}).get('severity', 'Unknown')}
**Message**: {issue.get('extra', {}).get('message', 'No message')}
**File**: {issue.get('path', 'Unknown')}
**Line**: {issue.get('start', {}).get('line', 'Unknown')}
**Code**:
```
{issue.get('extra', {}).get('lines', 'No code available')}
```

Provide:
1. A brief explanation of the vulnerability (2-3 sentences)
2. Why this is dangerous (1-2 sentences)
3. How to fix it with example code (if applicable)

Keep it concise and practical.
"""
        
        try:
            response = self.client.models.generate_content(
                model=self.model_name,
                contents=prompt
            )
            return response.text
        except Exception as e:
            return f"AI analysis unavailable: {str(e)}"
    
    def ai_generate_executive_summary(self, scan_results: Dict[str, Any]) -> str:
        """
        Use Gemini AI to generate an executive summary of all findings
        
        Args:
            scan_results: Complete Semgrep scan results
            
        Returns:
            AI-generated executive summary
        """
        results = scan_results.get('results', [])
        
        if not results:
            return "✅ No security vulnerabilities found. The code appears to be secure."
        
        # Prepare summary data
        severity_counts = {}
        vulnerability_types = {}
        
        for issue in results:
            severity = issue.get('extra', {}).get('severity', 'UNKNOWN')
            check_id = issue.get('check_id', 'Unknown')
            
            severity_counts[severity] = severity_counts.get(severity, 0) + 1
            vulnerability_types[check_id] = vulnerability_types.get(check_id, 0) + 1
        
        prompt = f"""
You are a security analyst preparing an executive summary. Based on the security scan results:

**Total Vulnerabilities**: {len(results)}
**Severity Distribution**: {json.dumps(severity_counts, indent=2)}
**Top Vulnerability Types**: {json.dumps(list(vulnerability_types.items())[:5], indent=2)}

Create a brief executive summary (3-4 paragraphs) that:
1. Summarizes the overall security posture
2. Highlights the most critical issues
3. Recommends priority actions
4. Provides a risk assessment

Use clear, non-technical language suitable for management.
"""
        
        try:
            response = self.client.models.generate_content(
                model=self.model_name,
                contents=prompt
            )
            return response.text
        except Exception as e:
            return f"AI summary unavailable: {str(e)}"
    
    def format_results_with_ai(self, scan_results: Dict[str, Any], include_ai_analysis: bool = True) -> str:
        """
        Format scan results with optional AI analysis
        
        Args:
            scan_results: Raw Semgrep scan results
            include_ai_analysis: Whether to include AI analysis for each issue
            
        Returns:
            Formatted report string with AI insights
        """
        results = scan_results.get('results', [])
        errors = scan_results.get('errors', [])
        
        if not results and not errors:
            return "✅ No security issues found! The code looks clean."
        
        report = []
        report.append("=" * 80)
        report.append("🤖 AI-POWERED SECURITY SCAN REPORT")
        report.append("=" * 80)
        
        # AI Executive Summary
        print("\n🤖 Generating AI Executive Summary...")
        executive_summary = self.ai_generate_executive_summary(scan_results)
        report.append("\n📊 EXECUTIVE SUMMARY (AI-Generated)")
        report.append("=" * 80)
        report.append(executive_summary)
        report.append("\n" + "=" * 80)
        
        report.append(f"\nTotal Issues Found: {len(results)}")
        report.append("")
        
        # Group by severity
        severity_groups = {}
        for issue in results:
            severity = issue.get('extra', {}).get('severity', 'INFO')
            if severity not in severity_groups:
                severity_groups[severity] = []
            severity_groups[severity].append(issue)
        
        # Display by severity
        for severity in ['ERROR', 'WARNING', 'INFO']:
            if severity in severity_groups:
                issues = severity_groups[severity]
                report.append(f"\n{'='*80}")
                report.append(f"🔴 {severity} LEVEL ISSUES ({len(issues)} found)")
                report.append(f"{'='*80}")
                
                for idx, issue in enumerate(issues, 1):
                    report.append(f"\n{idx}. {issue.get('check_id', 'Unknown')}")
                    report.append(f"   Severity: {severity}")
                    report.append(f"   Message: {issue.get('extra', {}).get('message', 'No message')}")
                    report.append(f"   File: {issue.get('path', 'Unknown')}")
                    report.append(f"   Line: {issue.get('start', {}).get('line', 'Unknown')}")
                    
                    # Show code snippet
                    code = issue.get('extra', {}).get('lines', '')
                    if code:
                        report.append(f"   Code:")
                        for line in code.strip().split('\n'):
                            report.append(f"      {line}")
                    
                    # AI Analysis for critical issues
                    if include_ai_analysis and severity in ['ERROR', 'WARNING']:
                        print(f"   🤖 Analyzing issue {idx}/{len(issues)}...")
                        ai_analysis = self.ai_analyze_vulnerability(issue)
                        report.append(f"\n   🤖 AI ANALYSIS:")
                        for line in ai_analysis.split('\n'):
                            report.append(f"   {line}")
                        report.append("")
        
        if errors:
            report.append(f"\n{'='*80}")
            report.append(f"SCAN ERRORS ({len(errors)} found)")
            report.append(f"{'='*80}")
            for error in errors:
                report.append(f"  - {error}")
        
        report.append("\n" + "=" * 80)
        
        return "\n".join(report)
    
    def scan_github_repo(self, repo_url: str, rules: str = "auto", include_ai_analysis: bool = True) -> str:
        """
        Main method to scan a GitHub repository with AI analysis
        
        Args:
            repo_url: GitHub repository URL
            rules: Semgrep rules to use (default: "auto")
            include_ai_analysis: Whether to include AI analysis
            
        Returns:
            Formatted security scan report with AI insights
        """
        temp_dir = None
        
        try:
            # Create temporary directory
            temp_dir = tempfile.mkdtemp(prefix="security_scan_")
            
            # Clone repository
            repo_path = self.clone_repository(repo_url, temp_dir)
            
            # Run scan
            scan_results = self.run_semgrep_scan(repo_path, rules)
            
            # Format and return results with AI analysis
            report = self.format_results_with_ai(scan_results, include_ai_analysis)
            
            return report
            
        except Exception as e:
            return f"❌ Error during security scan: {str(e)}"
            
        finally:
            # Cleanup temporary directory
            if temp_dir and os.path.exists(temp_dir):
                shutil.rmtree(temp_dir)
                print(f"Cleaned up temporary directory: {temp_dir}")
    
    def chat_about_vulnerability(self, question: str, context: str = "") -> str:
        """
        Chat with AI about security vulnerabilities
        
        Args:
            question: User's question about security
            context: Optional context from scan results
            
        Returns:
            AI response
        """
        prompt = f"""
You are a security expert. Answer this question about security vulnerabilities:

Question: {question}

{f'Context from scan: {context}' if context else ''}

Provide a clear, practical answer.
"""
        
        try:
            response = self.client.models.generate_content(
                model=self.model_name,
                contents=prompt
            )
            return response.text
        except Exception as e:
            return f"Error: {str(e)}"

print("✅ AISecurityScannerAgent class defined successfully!")
# Out:
# ✅ AISecurityScannerAgent class defined successfully!

# %% [markdown]
# ## Cell 6: Create and Test AI Agent Locally

# %%
# Create AI agent instance
ai_agent = AISecurityScannerAgent(gemini_api_key=GEMINI_API_KEY)

print("🤖 AI Security Scanner Agent initialized!")
print("🔍 Running security scan on sample_app.py with AI analysis...\n")

# Scan the current directory (includes sample_app.py)
scan_results = ai_agent.run_semgrep_scan(".", rules="auto")
report = ai_agent.format_results_with_ai(scan_results, include_ai_analysis=True)

print(report)
# Out:
# 🤖 AI Security Scanner Agent initialized!
# 🔍 Running security scan on sample_app.py with AI analysis...
#
# Running Semgrep scan on: .
# Scan completed. Found 38 issues
#
# 🤖 Generating AI Executive Summary...
#    🤖 Analyzing issue 1/26...
#    🤖 Analyzing issue 2/26...
#    🤖 Analyzing issue 3/26...
#    🤖 Analyzing issue 4/26...
#    🤖 Analyzing issue 5/26...
#    🤖 Analyzing issue 6/26...
#    🤖 Analyzing issue 7/26...
#    🤖 Analyzing issue 8/26...
#    🤖 Analyzing issue 9/26...
#    🤖 Analyzing issue 10/26...
#    🤖 Analyzing issue 11/26...
#    🤖 Analyzing issue 12/26...
#    🤖 Analyzing issue 13/26...
#    🤖 Analyzing issue 14/26...
#    🤖 Analyzing issue 15/26...
#    🤖 Analyzing issue 16/26...
#    🤖 Analyzing issue 17/26...
#    🤖 Analyzing issue 18/26...
#    🤖 Analyzing issue 19/26...
#    🤖 Analyzing issue 20/26...
#    🤖 Analyzing issue 21/26...
#    🤖 Analyzing issue 22/26...
#    🤖 Analyzing issue 23/26...
#    🤖 Analyzing issue 24/26...
#    🤖 Analyzing issue 25/26...
#    🤖 Analyzing issue 26/26...
#    🤖 Analyzing issue 1/10...
#    🤖 Analyzing issue 2/10...
#    🤖 Analyzing issue 3/10...
#    🤖 Analyzing issue 4/10...
#    🤖 Analyzing issue 5/10...
#    🤖 Analyzing issue 6/10...
#    🤖 Analyzing issue 7/10...
#    🤖 Analyzing issue 8/10...
#    🤖 Analyzing issue 9/10...
#    🤖 Analyzing issue 10/10...
# ================================================================================
# 🤖 AI-POWERED SECURITY SCAN REPORT
# ================================================================================
#
# 📊 EXECUTIVE SUMMARY (AI-Generated)
# ================================================================================
# **Executive Summary: Security Scan Results**
#
# Our recent security scan identified a total of 38 vulnerabilities. While the majority are categorized as "ERROR" and "WARNING" severity, indicating potential security risks, a smaller number are classified as informational. These results suggest there are areas within our systems and codebase that require immediate attention to mitigate potential threats and strengthen our overall security posture.
#
# The most critical issues uncovered revolve around exposed credentials and insecure communication protocols. The scan revealed a significant number of detected JWT (JSON Web Token) and Google OAuth access tokens, suggesting potential exposure of sensitive authentication credentials. Additionally, the presence of insecure HTTP requests in Python code and plaintext HTTP links within HTML documents indicates a vulnerability to "man-in-the-middle" attacks and data interception. These issues represent the most immediate risks to our organization.
#
# We strongly recommend prioritizing the remediation of exposed credentials and the implementation of secure communication protocols. Specifically, steps should be taken to immediately invalidate any compromised tokens and implement secure storage and handling procedures for all authentication credentials. Developers must also update Python code to utilize HTTPS instead of HTTP for all requests and ensure all links within HTML documents are encrypted via HTTPS.
#
# Given the nature of the vulnerabilities identified, the overall risk is considered moderate to high. The potential exposure of authentication credentials and the use of insecure communication protocols could lead to unauthorized access to sensitive data and systems, as well as potential data breaches and reputational damage. Swift and decisive action is needed to address these vulnerabilities and mitigate these risks.
#
#
# ================================================================================
#
# Total Issues Found: 38
#
#
# ================================================================================
# 🔴 ERROR LEVEL ISSUES (26 found)
# ================================================================================
#
# 1. generic.secrets.security.detected-jwt-token.detected-jwt-token
#    Severity: ERROR
#    Message: JWT token detected
#    File: .cache/pip/http-v2/d/6/a/5/d/d6a5d0856a7e93554e8be85cae6a61e3c3d38bd36521d22d8c0dc50e.body
#    Line: 44
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    **1. Explanation:** The code analysis tool has detected a potential JWT (JSON Web Token) within a file. This suggests a JWT secret key or token itself might be inadvertently stored in the source code or a temporary file, which should never happen.
#
#    **2. Danger:** If the detected JWT is a valid, active token, unauthorized individuals could use it to impersonate the associated user. If it's a secret key used for signing JWTs, attackers can forge tokens, gaining complete control.
#
#    **3. Fix:**
#
#    *   **Never store JWT secrets or tokens in code or files accessible to the codebase**.
#    *   **For secrets, use environment variables or secure configuration management tools** (e.g., HashiCorp Vault, AWS Secrets Manager).
#    *   **For tokens, ensure they are properly handled and securely stored** in the user's browser (e.g., using HTTP-only cookies) or a secure backend session.
#    *   **Inspect the file (.cache/pip/http-v2/...) and identify how the token/secret ended up there.** Secure your pip install process and consider using `--no-cache-dir`.
#
#    ```python
#    # Example: Instead of hardcoding a secret
#    import os
#
#    jwt_secret = os.environ.get("JWT_SECRET")  # Retrieve from environment variable
#
#    if jwt_secret:
#        # Use jwt_secret to sign/verify tokens
#        pass
#    else:
#        print("ERROR: JWT_SECRET not set in environment.")
#    ```
#
#
#
# 2. generic.secrets.security.detected-jwt-token.detected-jwt-token
#    Severity: ERROR
#    Message: JWT token detected
#    File: .cache/pip/http-v2/e/b/5/4/a/eb54ad8098bbce2484999b06578a3689563ea077088029e738ccebf4.body
#    Line: 89
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    Here's a breakdown of the JWT token vulnerability:
#
#    1.  **Explanation:** A JWT (JSON Web Token) was detected within a file, specifically in the `requires login` code snippet. JWTs are used for authentication and authorization, and shouldn't be stored in source code or cached files.
#
#    2.  **Why it's dangerous:**  If an attacker gains access to this file, they can extract the JWT and potentially impersonate a user or gain unauthorized access to protected resources. This bypasses the intended authentication mechanisms.
#
#    3.  **How to fix it:**
#
#        *   **Never store JWTs in source code or cache files.**  Instead, obtain them during the login process and store them securely (e.g., in a browser cookie with `HttpOnly` and `Secure` flags, or in a secure storage mechanism on the server-side).
#        *   **If the JWT is hardcoded for testing purposes, remove it and use a dedicated testing account.**
#        *   **Implement proper environment variable handling:** If you absolutely must use a JWT for local development, store it in an environment variable instead of hardcoding it.
#        *   **Rotate the JWT if you suspect it has been compromised.**
#
#        **Example (using environment variables):**
#
#        Instead of:
#
#        ```python
#        jwt_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIxMjM0NTY3ODkwIiwibmFtZSI6IkpvaG4gRG9lIiwiaWF0IjoxNTE2MjM5MDIyfQ.SflKxwRJSMeKKF2QT4fwpMeJf36POk6yJV_adQssw5c" # DO NOT DO THIS
#
#        # Use the JWT token
#        # headers = {'Authorization': f'Bearer {jwt_token}'}
#        ```
#
#        Use:
#
#        ```python
#        import os
#
#        jwt_token = os.environ.get("MY_JWT_TOKEN")
#
#        if jwt_token:
#            # Use the JWT token
#            # headers = {'Authorization': f'Bearer {jwt_token}'}
#            pass
#        else:
#            print("JWT_TOKEN environment variable not set!")
#
#        ```
#
#        Then, set the `MY_JWT_TOKEN` environment variable. **Important:**  Even with environment variables, avoid committing these values to version control. Use `.env` files (ignored by Git) for local development only.  For production, use secure configuration management.
#
#
#
# 3. generic.secrets.security.detected-google-oauth-access-token.detected-google-oauth-access-token
#    Severity: ERROR
#    Message: Google OAuth Access Token detected
#    File: .config/gcloud/logs/2025.12.19/18.07.04.310014.log
#    Line: 25
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    Here's an analysis of the provided vulnerability:
#
#    1.  **Explanation:** The code contains a Google OAuth Access Token, which grants unauthorized access to a Google user's data and resources. The token was found within a log file, indicating accidental or intentional storage in an insecure location.
#
#    2.  **Why it's dangerous:** An exposed token can be used by malicious actors to impersonate the legitimate user, accessing sensitive information (emails, documents, etc.) and potentially performing actions on their behalf (sending emails, modifying data).
#
#    3.  **How to fix it:**
#        *   **Never store tokens in logs or configuration files.** Rotate the compromised token immediately.
#        *   Use secure storage mechanisms like encrypted databases or dedicated secret management systems (e.g., HashiCorp Vault, AWS Secrets Manager).
#        *   Implement proper access control to restrict who can access the secrets.
#        *   Review your logging configurations to ensure tokens are never inadvertently logged.
#
#    No specific code is provided to analyze beyond the 'requires login' statement, which is irrelevant to the vulnerability itself. The fix lies in securing the storage and handling of the OAuth token itself, not that line of code.
#
#
#
# 4. generic.secrets.security.detected-jwt-token.detected-jwt-token
#    Severity: ERROR
#    Message: JWT token detected
#    File: .config/gcloud/logs/2025.12.19/18.07.04.310014.log
#    Line: 26
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    **1. Explanation:** A JSON Web Token (JWT) has been detected in a log file. This token likely contains sensitive information used for authentication and authorization.
#
#    **2. Why Dangerous:** Leaked JWTs can allow unauthorized individuals to impersonate legitimate users and gain access to protected resources. If the token's expiry isn't immediate and the signing key isn't compromised after revocation, the attacker can use the token until expiry.
#
#    **3. Fix:** Prevent JWTs from being logged. Redact or mask JWTs before logging them, or better yet, avoid logging authentication data entirely.
#        Example (Python):
#
#        ```python
#        import re
#
#        def sanitize_log_message(message):
#          """Removes JWT tokens from a log message."""
#          jwt_pattern = r"eyJ[a-zA-Z0-9_-]*\.eyJ[a-zA-Z0-9_-]*\.[a-zA-Z0-9_-]*"  # simplified JWT regex
#          return re.sub(jwt_pattern, "[REDACTED JWT]", message)
#
#        log_message = "User logged in with JWT: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIxMjM0NTY3ODkwIiwibmFtZSI6IkpvaG4gRG9lIiwiaWF0IjoxNTE2MjM5MDIyfQ.SflKxwRJSMeKKF2QT4fwpMeJf36POk6yJV_adQssw5c"
#        sanitized_message = sanitize_log_message(log_message)
#        print(sanitized_message) # Output: User logged in with JWT: [REDACTED JWT]
#
#        # Use sanitized_message when logging. For example:
#        # logger.info(sanitize_log_message(message_to_log))
#        ```
#
#       Ensure you use a robust regex tailored to your JWT format in production. Investigate *why* the token is being logged in the first place and address the root cause.
#
#
#
# 5. generic.secrets.security.detected-google-oauth-access-token.detected-google-oauth-access-token
#    Severity: ERROR
#    Message: Google OAuth Access Token detected
#    File: .config/gcloud/logs/2025.12.19/18.10.54.716352.log
#    Line: 25
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    Here's a breakdown of the identified vulnerability:
#
#    1.  **Explanation:** The vulnerability `generic.secrets.security.detected-google-oauth-access-token.detected-google-oauth-access-token` signifies that a Google OAuth Access Token has been detected within a log file.  These tokens are used to authenticate users and grant applications access to Google services on their behalf.
#
#    2.  **Why it's dangerous:** Exposing an OAuth access token allows malicious actors to impersonate the associated user and gain unauthorized access to their Google account data, potentially leading to data breaches, financial loss, or other security compromises.
#
#    3.  **How to fix it:**
#        *   **Immediately revoke the exposed token:** Go to your Google account security settings and revoke the detected access token.
#        *   **Implement proper logging practices:**
#            *   **Avoid logging sensitive data:**  Redesign your logging to exclude access tokens or other secrets. If logging is necessary, redact the token.
#            *   **Secure your log files:**  Ensure that log files are stored securely with appropriate access controls to prevent unauthorized access.
#
#        Example code (redaction in Python):
#
#        ```python
#        import re
#
#        def redact_token(log_message):
#          """Redacts Google OAuth access tokens from a log message."""
#          token_pattern = r"ya29\.[0-9a-zA-Z\-_]+"  # Example token pattern
#          redacted_message = re.sub(token_pattern, "<REDACTED_TOKEN>", log_message)
#          return redacted_message
#
#        # Example usage:
#        log_message = "Authorization: Bearer ya29.A0GeUhUC..."
#        redacted_log_message = redact_token(log_message)
#        print(redacted_log_message) # Output: Authorization: Bearer <REDACTED_TOKEN>
#        ```
#
#        **Important Considerations:**
#
#        *   **Token Rotation:** Implement regular token rotation to limit the impact of compromised tokens.
#        *   **Environment Variables/Secrets Management:**  Store access tokens securely using environment variables or a dedicated secrets management system instead of hardcoding them or logging them.  Never commit secrets to source control.
#        *   **Review the Code:**  Carefully review the code that generated the log to understand how the token ended up in the log and to prevent this from happening again.
#
#
#
# 6. generic.secrets.security.detected-jwt-token.detected-jwt-token
#    Severity: ERROR
#    Message: JWT token detected
#    File: .config/gcloud/logs/2025.12.19/18.10.54.716352.log
#    Line: 26
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    Here's an analysis of the detected JWT token vulnerability:
#
#    1. **Explanation:** A JSON Web Token (JWT) has been detected within a log file. This suggests a secret key or other sensitive authorization information may be inadvertently exposed.
#
#    2. **Danger:** If an attacker gains access to this JWT, they can impersonate the user or service associated with it, gaining unauthorized access to resources.
#
#    3. **Fix:** **Never store JWTs or other secrets in log files or configuration files that aren't properly secured (ideally encrypted).** Implement proper secret management practices such as using environment variables, a dedicated secret store (HashiCorp Vault, AWS Secrets Manager, etc.), or key management services. Redact or remove JWTs from logs before they are written or implement stricter access controls on the log files.
#
#       **Example (using environment variables in code, avoid hardcoding):**
#
#       ```python
#       import os
#       import jwt
#
#       # Insecure (AVOID):
#       # secret = "hardcoded_secret"
#
#       # Secure (using environment variable):
#       secret = os.environ.get("JWT_SECRET_KEY")
#       if not secret:
#           raise ValueError("JWT_SECRET_KEY environment variable not set!")
#
#       # Example of JWT creation (for demonstration only, implement securely)
#       payload = {'user_id': 123}
#       encoded_jwt = jwt.encode(payload, secret, algorithm="HS256")
#
#       # DON'T log encoded_jwt directly!
#       # Instead, log context, *without* the JWT itself
#       print("User logged in, ID:", payload['user_id'])
#
#       #When needing the token, use it immediately and do NOT store it.
#       #For example, passing it in an Authorization header:
#       #requests.get('api/protected', headers={'Authorization': f'Bearer {encoded_jwt}'})
#       ```
#
#       **Important:** Ensure the environment variable containing the secret is itself securely managed and not exposed. Ensure log files have restrictive access permissions.
#
#
#
# 7. generic.secrets.security.detected-google-oauth-access-token.detected-google-oauth-access-token
#    Severity: ERROR
#    Message: Google OAuth Access Token detected
#    File: .config/gcloud/logs/2025.12.19/18.10.54.738034.log
#    Line: 25
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    Here's a breakdown of the security issue:
#
#    1. **Explanation:** A Google OAuth Access Token was found within a log file. This suggests the token may have been inadvertently logged, potentially exposing it to unauthorized access.
#
#    2. **Why Dangerous:** Access tokens grant significant permissions, potentially allowing attackers to impersonate the user, access their Google account data (email, calendar, drive), and perform actions on their behalf.
#
#    3. **How to Fix:**
#
#       *   **Token Handling:**  Never log access tokens or other sensitive credentials.  Implement proper credential management using environment variables, secure storage (e.g., KMS, Vault), or dedicated credential management libraries.
#       *   **Log Scrubbing:**  Implement log scrubbing to automatically detect and redact sensitive information before logging.
#
#       **Example (Python using environment variables):**
#
#       ```python
#       import os
#       from google.oauth2 import credentials
#
#       # Instead of hardcoding or logging the token:
#       # token = "..."
#
#       # Retrieve the token from an environment variable
#       token = os.environ.get("GOOGLE_OAUTH_TOKEN")
#
#       if token:
#           creds = credentials.Credentials(token)
#           # Use the creds object to make authenticated API calls
#           # ...
#       else:
#           print("Error: GOOGLE_OAUTH_TOKEN environment variable not set.")
#       ```
#
#        **Important:** Immediately revoke the compromised token from the Google Cloud Console or the user's Google account.  Review your logging configuration and code to prevent future exposure of credentials. Also, investigate how the token ended up in the logs to understand the root cause.
#
#
#
# 8. generic.secrets.security.detected-jwt-token.detected-jwt-token
#    Severity: ERROR
#    Message: JWT token detected
#    File: .config/gcloud/logs/2025.12.19/18.10.54.738034.log
#    Line: 26
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    1.  **Explanation:** A JWT (JSON Web Token) was found in a log file.  This suggests a secret, used for authentication and authorization, is inadvertently exposed.
#
#    2.  **Why dangerous:** If an attacker obtains the JWT, they can impersonate the user associated with that token and gain unauthorized access to the system or data.
#
#    3.  **Fix:**
#        *   **Never log JWTs:** Redact or filter JWTs before logging. Replace the token with a placeholder.
#        *   **Rotate Secrets:** Immediately revoke the compromised JWT and issue new ones.
#        *   **Secure Storage:** Store secrets using dedicated secret management solutions (e.g., HashiCorp Vault, AWS Secrets Manager, Google Cloud Secret Manager).
#        *   **Code Example (Python, logging module - illustrative):**
#
#        ```python
#        import logging
#        import re
#
#        # Configure logging
#        logging.basicConfig(level=logging.INFO)
#        logger = logging.getLogger(__name__)
#
#        def sanitize_log_message(message):
#            """Replaces JWTs in a log message with '[REDACTED]'."""
#            jwt_pattern = r"eyJ[a-zA-Z0-9_-]*\.eyJ[a-zA-Z0-9_-]*\.[a-zA-Z0-9_-]*"  # Simplified JWT pattern
#            return re.sub(jwt_pattern, "[REDACTED]", message)
#
#        # Example usage
#        sensitive_data = "Some data with a JWT: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIxMjM0NTY3ODkwIiwibmFtZSI6IkpvaG4gRG9lIiwiaWF0IjoxNTE2MjM5MDIyfQ.SflKxwRJSMeKKF2QT4fwpMeJf36POk6yJV_adQssw5c and some other data."
#        sanitized_message = sanitize_log_message(sensitive_data)
#        logger.info(sanitized_message) # Outputs: Some data with a JWT: [REDACTED] and some other data.
#        ```
#        **Important:** This example uses a simplified JWT pattern.  A more robust pattern may be needed for real-world scenarios.  Ensure the pattern doesn't redact legitimate data. Also, ensure your logging configuration is set up to use this sanitization function or similar techniques.  Furthermore, consider using a logging framework that natively supports sensitive data filtering.
#
#
#
# 9. generic.secrets.security.detected-google-oauth-access-token.detected-google-oauth-access-token
#    Severity: ERROR
#    Message: Google OAuth Access Token detected
#    File: .config/gcloud/logs/2025.12.19/18.10.55.699665.log
#    Line: 6
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    Here's a concise analysis of the Google OAuth Access Token vulnerability:
#
#    1. **Explanation:** The vulnerability indicates a Google OAuth Access Token was found within a log file. This token grants access to a Google account and its associated services.
#
#    2. **Why Dangerous:** If an attacker gains access to this token, they can impersonate the legitimate user, accessing their data, sending emails, and potentially gaining control of other services connected to the Google account.
#
#    3. **How to Fix:**
#        * **Immediately revoke the compromised token:**  In the Google Cloud Console (or relevant Google service), find the authorized app associated with the token and revoke its access.
#        * **Rotate credentials:**  Re-authenticate your application and generate new access tokens.
#        * **Implement proper secrets management:**  Never store tokens directly in log files or code. Use secure storage solutions like HashiCorp Vault, environment variables, or cloud provider secrets managers.  Ensure your application uses these tools to retrieve tokens at runtime instead of embedding them directly.
#        * **Sanitize Logs:** Implement logging procedures to scrub sensitive information, including access tokens, from log files before they are written to disk. This can involve regular expression-based searches and replacements.
#
#        **Example (Python using environment variables):**
#        ```python
#        import os
#        from google.oauth2 import credentials
#        from googleapiclient.discovery import build
#
#        # Retrieve access token from environment variable
#        token = os.environ.get("GOOGLE_OAUTH_TOKEN")
#
#        if token:
#            creds = credentials.Credentials(token)
#            service = build('drive', 'v3', credentials=creds)
#            # ... use the Google Drive service ...
#        else:
#            print("Error: Google OAuth token not found in environment variables.")
#        ```
#        **Important:** The above code assumes you have obtained the token and stored it securely in the environment.  Do NOT hardcode the token directly in the code or in your logs.
#
#
#
# 10. generic.secrets.security.detected-google-oauth-access-token.detected-google-oauth-access-token
#    Severity: ERROR
#    Message: Google OAuth Access Token detected
#    File: .config/gcloud/logs/2025.12.19/18.14.59.196160.log
#    Line: 6
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    Here's a concise analysis of the provided security issue:
#
#    1.  **Explanation:** A Google OAuth Access Token has been found within a log file (`.config/gcloud/logs/2025.12.19/18.14.59.196160.log`).  Access tokens are used to authorize access to Google services on behalf of a user.
#
#    2.  **Why Dangerous:** If an attacker gains access to this token, they can impersonate the user and access their Google services (Gmail, Drive, etc.), potentially leading to data breaches and unauthorized actions.
#
#    3.  **How to Fix:**
#
#        *   **Immediately Revoke the Token:** If you know which user and application the token belongs to, revoke the token in the Google Cloud Console (or Google Account security settings). This immediately invalidates the compromised token.
#
#        *   **Prevent Token Logging:**  Review the code that generated the log file.  Modify it to avoid logging sensitive information like access tokens.  Use a logging library that allows for masking or filtering sensitive data.
#
#        *   **Example (Python):**
#
#        ```python
#        import logging
#
#        # Configure logging (e.g., to a file)
#        logging.basicConfig(filename='myapp.log', level=logging.INFO)
#
#        def log_data(data):
#            # Securely log data, masking sensitive fields
#            masked_data = {}
#            for key, value in data.items():
#                if key.lower() == "accesstoken":
#                    masked_data[key] = "***REDACTED***" #Or replace with a hash of the token
#                else:
#                    masked_data[key] = value
#            logging.info(f"Data processed: {masked_data}")
#        ```
#
#        *   **Token Management:** Use a secure method to manage credentials (e.g., environment variables, HashiCorp Vault, Google Secret Manager). Never hardcode or log access tokens. Use refresh tokens to obtain new access tokens as needed without storing long-lived access tokens directly.
#
#        *   **Log Rotation & Security:** Implement robust log rotation and access control to limit exposure if sensitive information is inadvertently logged.  Regularly audit logs for sensitive data.
#
#    After taking these steps, *regenerate* a *new* access token, as the old one must be considered compromised. Also, investigate how the token was logged in the first place to prevent future occurrences.
#
#
#
# 11. generic.secrets.security.detected-google-oauth-access-token.detected-google-oauth-access-token
#    Severity: ERROR
#    Message: Google OAuth Access Token detected
#    File: .config/gcloud/logs/2025.12.19/18.16.06.179270.log
#    Line: 6
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 12. generic.secrets.security.detected-google-oauth-access-token.detected-google-oauth-access-token
#    Severity: ERROR
#    Message: Google OAuth Access Token detected
#    File: .config/gcloud/logs/2025.12.19/18.21.14.705027.log
#    Line: 6
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'model': 'gemini-2.0-flash-exp', 'location': 'global'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 13. generic.secrets.security.detected-google-oauth-access-token.detected-google-oauth-access-token
#    Severity: ERROR
#    Message: Google OAuth Access Token detected
#    File: .config/gcloud/logs/2025.12.19/18.27.23.836855.log
#    Line: 6
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 14. generic.secrets.security.detected-google-oauth-access-token.detected-google-oauth-access-token
#    Severity: ERROR
#    Message: Google OAuth Access Token detected
#    File: .config/gcloud/logs/2025.12.19/18.33.32.748298.log
#    Line: 6
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 15. generic.secrets.security.detected-google-oauth-access-token.detected-google-oauth-access-token
#    Severity: ERROR
#    Message: Google OAuth Access Token detected
#    File: .config/gcloud/logs/2025.12.19/18.33.41.878788.log
#    Line: 25
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 16. generic.secrets.security.detected-jwt-token.detected-jwt-token
#    Severity: ERROR
#    Message: JWT token detected
#    File: .config/gcloud/logs/2025.12.19/18.33.41.878788.log
#    Line: 26
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'model': 'gemini-2.0-flash-exp', 'location': 'global'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 17. generic.secrets.security.detected-google-oauth-access-token.detected-google-oauth-access-token
#    Severity: ERROR
#    Message: Google OAuth Access Token detected
#    File: .config/gcloud/logs/2025.12.19/18.39.42.993381.log
#    Line: 6
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 18. python.django.security.injection.tainted-sql-string.tainted-sql-string
#    Severity: ERROR
#    Message: Detected user input used to manually construct a SQL string. This is usually bad practice because manual construction could accidentally result in a SQL injection. An attacker could use a SQL injection to steal or modify contents of the database. Instead, use a parameterized query which is available by default in most database engines. Alternatively, consider using the Django object-relational mappers (ORM) instead of raw SQL queries.
#    File: sample_app.py
#    Line: 25
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 19. python.flask.security.injection.tainted-sql-string.tainted-sql-string
#    Severity: ERROR
#    Message: Detected user input used to manually construct a SQL string. This is usually bad practice because manual construction could accidentally result in a SQL injection. An attacker could use a SQL injection to steal or modify contents of the database. Instead, use a parameterized query which is available by default in most database engines. Alternatively, consider using an object-relational mapper (ORM) such as SQLAlchemy which will protect your queries.
#    File: sample_app.py
#    Line: 25
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 20. python.sqlalchemy.security.sqlalchemy-execute-raw-query.sqlalchemy-execute-raw-query
#    Severity: ERROR
#    Message: Avoiding SQL string concatenation: untrusted input concatenated with raw SQL query can result in SQL Injection. In order to execute raw query safely, prepared statement should be used. SQLAlchemy provides TextualSQL to easily used prepared statement with named parameters. For complex SQL composition, use SQL Expression Language or Schema Definition Language. In most cases, SQLAlchemy ORM will be a better option.
#    File: sample_app.py
#    Line: 26
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 21. python.django.security.injection.command.command-injection-os-system.command-injection-os-system
#    Severity: ERROR
#    Message: Request data detected in os.system. This could be vulnerable to a command injection and should be avoided. If this must be done, use the 'subprocess' module instead and pass the arguments as a list. See https://owasp.org/www-community/attacks/Command_Injection for more information.
#    File: sample_app.py
#    Line: 33
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 22. python.flask.security.injection.os-system-injection.os-system-injection
#    Severity: ERROR
#    Message: User data detected in os.system. This could be vulnerable to a command injection and should be avoided. If this must be done, use the 'subprocess' module instead and pass the arguments as a list.
#    File: sample_app.py
#    Line: 35
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 23. python.lang.security.dangerous-system-call.dangerous-system-call
#    Severity: ERROR
#    Message: Found user-controlled data used in a system call. This could allow a malicious actor to execute commands. Use the 'subprocess' module instead, which is easier to use without accidentally exposing a command injection vulnerability.
#    File: sample_app.py
#    Line: 35
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 24. python.flask.security.insecure-deserialization.insecure-deserialization
#    Severity: ERROR
#    Message: Detected the use of an insecure deserialization library in a Flask route. These libraries are prone to code execution vulnerabilities. Ensure user data does not enter this function. To fix this, try to avoid serializing whole objects. Consider instead using a serializer such as JSON.
#    File: sample_app.py
#    Line: 43
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 25. python.flask.security.dangerous-template-string.dangerous-template-string
#    Severity: ERROR
#    Message: Found a template created with string formatting. This is susceptible to server-side template injection and cross-site scripting attacks.
#    File: sample_app.py
#    Line: 51
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 26. python.flask.security.injection.path-traversal-open.path-traversal-open
#    Severity: ERROR
#    Message: Found request data in a call to 'open'. Ensure the request data is validated or sanitized, otherwise it could result in path traversal attacks.
#    File: sample_app.py
#    Line: 59
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# ================================================================================
# 🔴 WARNING LEVEL ISSUES (10 found)
# ================================================================================
#
# 1. html.security.plaintext-http-link.plaintext-http-link
#    Severity: WARNING
#    Message: This link points to a plaintext HTTP URL. Prefer an encrypted HTTPS URL if possible.
#    File: .local/share/jupyter/runtime/jpserver-2515-open.html
#    Line: 13
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 2. python.django.security.injection.sql.sql-injection-using-db-cursor-execute.sql-injection-db-cursor-execute
#    Severity: WARNING
#    Message: User-controlled data from a request is passed to 'execute()'. This could lead to a SQL injection and therefore protected information could be leaked. Instead, use django's QuerySets, which are built with query parameterization and therefore not vulnerable to sql injection. For example, you could use `Entry.objects.filter(date=2006)`.
#    File: sample_app.py
#    Line: 21
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'model': 'gemini-2.0-flash-exp', 'location': 'global'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 3. python.lang.security.audit.formatted-sql-query.formatted-sql-query
#    Severity: WARNING
#    Message: Detected possible formatted SQL query. Use parameterized queries instead.
#    File: sample_app.py
#    Line: 26
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 4. python.flask.security.audit.directly-returned-format-string.directly-returned-format-string
#    Severity: WARNING
#    Message: Detected Flask route directly returning a formatted string. This is subject to cross-site scripting if user input can reach the string. Consider using the template engine instead and rendering pages with 'render_template()'.
#    File: sample_app.py
#    Line: 36
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 5. python.lang.security.deserialization.pickle.avoid-pickle
#    Severity: WARNING
#    Message: Avoid using `pickle`, which is known to lead to code execution vulnerabilities. When unpickling, the serialized data could be manipulated to run arbitrary code. Instead, consider serializing the relevant data as JSON or a similar text-based serialization format.
#    File: sample_app.py
#    Line: 43
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 6. python.django.security.injection.raw-html-format.raw-html-format
#    Severity: WARNING
#    Message: Detected user input flowing into a manually constructed HTML string. You may be accidentally bypassing secure methods of rendering HTML by manually constructing HTML and this could create a cross-site scripting vulnerability, which could let attackers steal sensitive user data. To be sure this is safe, check that the HTML is rendered safely. Otherwise, use templates (`django.shortcuts.render`) which will safely render HTML instead.
#    File: sample_app.py
#    Line: 51
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}
#
#
# 7. python.flask.security.injection.raw-html-concat.raw-html-format
#    Severity: WARNING
#    Message: Detected user input flowing into a manually constructed HTML string. You may be accidentally bypassing secure methods of rendering HTML by manually constructing HTML and this could create a cross-site scripting vulnerability, which could let attackers steal sensitive user data. To be sure this is safe, check that the HTML is rendered safely. Otherwise, use templates (`flask.render_template`) which will safely render HTML instead.
#    File: sample_app.py
#    Line: 51
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'model': 'gemini-2.0-flash-exp', 'location': 'global'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '26s'}]}}
#
#
# 8. python.flask.security.audit.render-template-string.render-template-string
#    Severity: WARNING
#    Message: Found a template created with string formatting. This is susceptible to server-side template injection and cross-site scripting attacks.
#    File: sample_app.py
#    Line: 52
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '26s'}]}}
#
#
# 9. python.flask.security.audit.app-run-param-config.avoid_app_run_with_bad_host
#    Severity: WARNING
#    Message: Running flask app with host 0.0.0.0 could expose the server publicly.
#    File: sample_app.py
#    Line: 70
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '26s'}]}}
#
#
# 10. python.flask.security.audit.debug-enabled.debug-enabled
#    Severity: WARNING
#    Message: Detected Flask app with debug=True. Do not deploy to production with this flag enabled as it will leak sensitive information. Instead, consider using Flask configuration variables or setting 'debug' using system environment variables.
#    File: sample_app.py
#    Line: 70
#    Code:
#       requires login
#
#    🤖 AI ANALYSIS:
#    AI analysis unavailable: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota. Please migrate to Gemini 2.5 Flash Image (models/gemini-2.5-flash-image) for higher quota limits. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_requests_per_model', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-exp'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '26s'}]}}
#
#
# ================================================================================
# 🔴 INFO LEVEL ISSUES (2 found)
# ================================================================================
#
# 1. python.lang.security.audit.insecure-transport.requests.request-with-http.request-with-http
#    Severity: INFO
#    Message: Detected a request using 'http://'. This request will be unencrypted, and attackers could listen into traffic on the network and be able to obtain sensitive information. Use 'https://' instead.
#    File: .ipython/profile_default/ipython_kernel_config.py
#    Line: 19
#    Code:
#       requires login
#
# 2. python.lang.security.audit.insecure-transport.requests.request-session-with-http.request-session-with-http
#    Severity: INFO
#    Message: Detected a request using 'http://'. This request will be unencrypted. Use 'https://' instead.
#    File: .jupyter/jupyter_notebook_config.py
#    Line: 41
#    Code:
#       requires login
#
# ================================================================================

# %% [markdown]
# ## Cell 7: Test AI Chat Feature
#
# Ask the AI agent questions about security vulnerabilities.

# %%
# Ask AI about SQL injection
question = "What is SQL injection and how can I prevent it in Python?"
answer = ai_agent.chat_about_vulnerability(question)

print(f"❓ Question: {question}\n")
print(f"🤖 AI Response:\n{answer}")
# Out:
# ❓ Question: What is SQL injection and how can I prevent it in Python?
#
# 🤖 AI Response:
# Okay, let's break down SQL injection and how to defend against it in Python.
#
# **What is SQL Injection?**
#
# SQL injection (SQLi) is a type of security vulnerability that occurs when a malicious user is able to insert (or "inject") arbitrary SQL code into a database query.  Essentially, they're tricking your application into executing commands that the developer never intended. This can lead to:
#
# *   **Data breaches:** Attackers can steal sensitive data like user credentials, financial information, or proprietary business data.
# *   **Data manipulation:** They can modify, delete, or insert data, potentially corrupting your database and impacting application functionality.
# *   **Authentication bypass:** Attackers might bypass login mechanisms and gain administrative access.
# *   **Denial-of-service (DoS):** In some cases, they can disrupt the availability of your application by overloading the database.
# *   **Remote code execution:** In worst-case scenarios (and often involving misconfigured databases), attackers might be able to execute arbitrary commands on the database server's operating system.
#
# **How does SQL Injection work? (Simplified Example)**
#
# Imagine you have a simple web form where users enter their username to retrieve their profile. The application might construct an SQL query like this:
#
# ```python
# username = input("Enter your username: ")  # Get user input (DANGEROUS!)
# query = "SELECT * FROM users WHERE username = '" + username + "'"  # Construct the query
# ```
#
# If a user enters a legitimate username like "john", the query becomes:
#
# ```sql
# SELECT * FROM users WHERE username = 'john'
# ```
#
# But, if a malicious user enters something like:
#
# ```
# ' OR '1'='1
# ```
#
# The resulting query becomes:
#
# ```sql
# SELECT * FROM users WHERE username = '' OR '1'='1'
# ```
#
# Because `'1'='1'` is always true, the query now effectively returns *all* rows from the `users` table, bypassing the username check entirely. This is a simplified example, but it illustrates how a carefully crafted input can change the meaning and behavior of your SQL query.  More complex attacks are possible to delete data, modify data, or even execute stored procedures.
#
# **How to Prevent SQL Injection in Python**
#
# The *only* reliable way to prevent SQL injection is to **never directly concatenate user-provided data into your SQL queries.** Instead, you must use **parameterized queries** (also known as prepared statements) or an Object-Relational Mapper (ORM) that handles parameterization for you.
#
# Here's a breakdown of how to use parameterized queries with popular Python database libraries:
#
# **1. Using `sqlite3` (for SQLite databases):**
#
# ```python
# import sqlite3
#
# # Connect to the database
# conn = sqlite3.connect('mydatabase.db')
# cursor = conn.cursor()
#
# # Get user input (NEVER directly embed this in the query!)
# username = input("Enter username: ")
# password = input("Enter password: ")
#
# # Use a parameterized query with placeholders
# query = "SELECT * FROM users WHERE username = ? AND password = ?"  # Use ? as placeholders
#
# # Provide the user input as a tuple to the execute method
# cursor.execute(query, (username, password)) # Pass username and password as a tuple
#
# # Fetch the results
# results = cursor.fetchall()
#
# # Process the results
# if results:
#     print("User found!")
#     # ... process user data
# else:
#     print("User not found.")
#
# # Close the connection
# conn.close()
# ```
#
# **Key points:**
#
# *   Instead of concatenating the `username` and `password` directly into the SQL query, we use placeholders (`?`).
# *   We pass the actual user input as a *tuple* to the `cursor.execute()` method.  The database driver/library takes care of properly escaping and quoting the values before they are inserted into the query. This is crucial because it treats the user input as *data*, not as part of the SQL command.
#
# **2. Using `psycopg2` (for PostgreSQL databases):**
#
# ```python
# import psycopg2
#
# # Replace with your database credentials
# db_params = {
#     'dbname': 'your_db',
#     'user': 'your_user',
#     'password': 'your_password',
#     'host': 'your_host'
# }
#
# try:
#     conn = psycopg2.connect(**db_params)
#     cursor = conn.cursor()
#
#     username = input("Enter username: ")
#     password = input("Enter password: ")
#
#     # Use parameterized query with %s placeholders (PostgreSQL uses %s)
#     query = "SELECT * FROM users WHERE username = %s AND password = %s"
#
#     # Pass username and password as a tuple
#     cursor.execute(query, (username, password))
#
#     results = cursor.fetchall()
#
#     if results:
#         print("User found!")
#         # ... process user data
#     else:
#         print("User not found.")
#
#     conn.commit() # Important to commit changes
# except psycopg2.Error as e:
#     print(f"Database error: {e}")
# finally:
#     if conn:
#         cursor.close()
#         conn.close()
# ```
#
# **Important Notes for `psycopg2`:**
#
# *   `psycopg2` is a powerful PostgreSQL adapter.  Make sure you install it (`pip install psycopg2-binary`).  The `-binary` version avoids the need for system-level PostgreSQL development headers in many cases.
# *   `psycopg2` uses `%s` as the placeholder style.  Other database adapters might use different placeholders (e.g., `%s`, `?`, `:name`). Check the documentation for your specific database driver.
# *   Always `commit()` your changes to the database after performing `INSERT`, `UPDATE`, or `DELETE` operations.
#
# **3. Using MySQL Connector/Python (for MySQL databases):**
#
# ```python
# import mysql.connector
#
# # Replace with your database credentials
# db_config = {
#     'user': 'your_user',
#     'password': 'your_password',
#     'host': 'your_host',
#     'database': 'your_db'
# }
#
# try:
#     conn = mysql.connector.connect(**db_config)
#     cursor = conn.cursor()
#
#     username = input("Enter username: ")
#     password = input("Enter password: ")
#
#     # Parameterized query with %s placeholders (MySQL uses %s)
#     query = "SELECT * FROM users WHERE username = %s AND password = %s"
#
#     # Pass username and password as a tuple
#     cursor.execute(query, (username, password))
#
#     results = cursor.fetchall()
#
#     if results:
#         print("User found!")
#         # ... process user data
#     else:
#         print("User not found.")
#
#     conn.commit()  # Important to commit changes
#
# except mysql.connector.Error as err:
#     print(f"Error: {err}")
#
# finally:
#     if conn:
#         cursor.close()
#         conn.close()
# ```
#
# **Important Notes for MySQL Connector/Python:**
#
# *   Install the connector: `pip install mysql-connector-python`
# *   Similar to `psycopg2`, it uses `%s` for placeholders by default.
# *   Remember to `commit()` after any changes.
#
# **4. Using an ORM (Object-Relational Mapper)**
#
# ORMs (like SQLAlchemy or Django's ORM) provide a higher-level abstraction over databases.  They generally handle parameterization automatically, reducing the risk of SQL injection.
#
# **Example using SQLAlchemy:**
#
# ```python
# from sqlalchemy import create_engine, Column, Integer, String
# from sqlalchemy.orm import sessionmaker
# from sqlalchemy.ext.declarative import declarative_base
#
# # Database URL (replace with your database connection string)
# DATABASE_URL = "sqlite:///./mydatabase.db"  # For SQLite
# #DATABASE_URL = "postgresql://user:password@host:port/database" # For PostgreSQL
#
# engine = create_engine(DATABASE_URL)
# SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)
#
# Base = declarative_base()
#
# class User(Base):
#     __tablename__ = "users"
#
#     id = Column(Integer, primary_key=True, index=True)
#     username = Column(String, unique=True, index=True)
#     password = Column(String)
#
# Base.metadata.create_all(bind=engine) # Create tables if they don't exist
#
#
# # Example usage:
# def get_user(username: str, password: str):
#     db = SessionLocal()
#     user = db.query(User).filter(User.username == username, User.password == password).first()
#     db.close()
#     return user
#
# username = input("Enter username: ")
# password = input("Enter password: ")
#
# user = get_user(username, password)
#
# if user:
#     print("User found:", user.username)
# else:
#     print("User not found.")
#
# ```
#
# **Key benefits of using an ORM:**
#
# *   **Abstraction:**  You work with Python objects instead of raw SQL.
# *   **Parameterization:** ORMs typically handle parameterization automatically, so you don't have to worry about it manually.
# *   **Database portability:**  Easier to switch between database systems.
# *   **Code readability:**  ORMs can make your database code more readable and maintainable.
#
# **Important Security Considerations:**
#
# *   **Never trust user input:** Always validate and sanitize user input, even when using parameterized queries or ORMs.  Check for length limits, allowed characters, and data types. Sanitize potentially dangerous characters (e.g., quotes, semicolons, etc.) if they're not supposed to be in the input.
# *   **Principle of Least Privilege:** Ensure that the database user account used by your application has only the minimum necessary privileges to perform its tasks.  Don't give the application's database user account `root` or `admin` privileges.
# *   **Keep your libraries up to date:** Regularly update your database drivers and ORM libraries to patch any security vulnerabilities.
# *   **Web application firewall (WAF):** Consider using a WAF to detect and block common SQL injection attempts at the network level.
# *   **Regular Security Audits:**  Have your code and infrastructure regularly audited by security professionals to identify potential vulnerabilities.
# *   **Defense in Depth:** Implement multiple layers of security to protect your application. Parameterized queries/ORMs are the first and most crucial line of defense, but they should be complemented by other security measures.
#
# **In Summary:**
#
# *   **Avoid string concatenation of user input in SQL queries at all costs.**
# *   **Use parameterized queries (prepared statements) with placeholders.**
# *   **Consider using an ORM to simplify database interaction and reduce the risk of SQL injection.**
# *   **Validate and sanitize user input.**
# *   **Apply the principle of least privilege.**
# *   **Keep your libraries updated.**
# *   **Employ additional security measures like WAFs and regular audits.**
#
# By following these guidelines, you can significantly reduce the risk of SQL injection vulnerabilities in your Python applications. Remember, security is an ongoing process, not a one-time fix.

# %% [markdown]
# ## Cell 8: Test with GitHub Repository (Optional)

# %%
# Test with a GitHub repository
# Replace with your repository URL
test_repo_url = "https://github.com/yourusername/your-repo.git"

# Uncomment to run (make sure to replace the URL first)
# print(f"🔍 Scanning GitHub repository with AI analysis: {test_repo_url}\n")
# report = ai_agent.scan_github_repo(test_repo_url, include_ai_analysis=True)
# print(report)

# %% [markdown]
# ## Cell 9: Create Agent Function for Vertex AI Deployment

# %%
class DeployableAIAgent:
    """Wrapper class for deployment to Vertex AI"""
    
    def __init__(self, gemini_api_key: str):
        """Initialize with Gemini API key"""
        self.gemini_api_key = gemini_api_key
        # Don't initialize the agent here - do it in query() instead
    
    def query(self, repo_url: str = None, rules: str = "auto", 
              include_ai_analysis: bool = True, question: str = None) -> str:
        """
        Query endpoint for the AI agent
        
        Args:
            repo_url: GitHub repository URL to scan (optional if just asking a question)
            rules: Semgrep rules to use (default: "auto")
            include_ai_analysis: Whether to include AI analysis (default: True)
            question: Optional question to ask the AI about security
            
        Returns:
            Security scan report with AI insights or answer to question
        """
        # Initialize agent here (not in __init__) to avoid pickle issues
        agent = AISecurityScannerAgent(gemini_api_key=self.gemini_api_key)
        
        # If just asking a question
        if question and not repo_url:
            return agent.chat_about_vulnerability(question)
        
        # If scanning a repository
        if repo_url:
            return agent.scan_github_repo(repo_url, rules, include_ai_analysis)
        
        return "Please provide either a repo_url to scan or a question to ask."

print("✅ DeployableAIAgent class created!")
# Out:
# ✅ DeployableAIAgent class created!

# %% [markdown]
# ## Cell 10: Initialize Vertex AI

# %%
from google.cloud import aiplatform

# Initialize Vertex AI
aiplatform.init(
    project=PROJECT_ID,
    location=LOCATION,
    staging_bucket=STAGING_BUCKET
)

print(f"✅ Vertex AI initialized")
print(f"   Project: {PROJECT_ID}")
print(f"   Location: {LOCATION}")
print(f"   Staging Bucket: {STAGING_BUCKET}")
# Out:
# ✅ Vertex AI initialized
#    Project: steam-aria-479903-s9
#    Location: us-central1
#    Staging Bucket: gs://dataset-bucket-imran

# %% [markdown]
# ## Cell 11: Deploy AI Agent to Vertex AI
#
# ⚠️ This may take 5-10 minutes to complete.

# %%
from vertexai.preview import reasoning_engines

print("🚀 Deploying AI Security Scanner Agent to Vertex AI...")
print("   This may take 5-10 minutes...\n")

# Create the reasoning engine with the deployable agent class
agent_app = reasoning_engines.ReasoningEngine.create(
    DeployableAIAgent(GEMINI_API_KEY),  # Pass the class instance, not a function
    requirements=[
        "google-cloud-aiplatform[reasoningengine]",
        "google-genai",  # Changed from google-generativeai
        "semgrep",
        "gitpython"
    ],
    display_name="ai-security-scanner-agent",
    description="AI-powered agent that scans GitHub repositories for security vulnerabilities using Semgrep and Gemini",
    extra_packages=[]
)

print(f"\n✅ AI Agent deployed successfully!")
print(f"\nResource name: {agent_app.resource_name}")
print(f"\n📝 Save this resource name for querying the agent later!")
# Out:
# 🚀 Deploying AI Security Scanner Agent to Vertex AI...
#    This may take 5-10 minutes...
#
# Using bucket dataset-bucket-imran
# Writing to gs://dataset-bucket-imran/reasoning_engine/reasoning_engine.pkl
# Writing to gs://dataset-bucket-imran/reasoning_engine/requirements.txt
# Creating in-memory tarfile of extra_packages
# Writing to gs://dataset-bucket-imran/reasoning_engine/dependencies.tar.gz
# Creating ReasoningEngine
# Create ReasoningEngine backing LRO: projects/104435755698/locations/us-central1/reasoningEngines/562186892351635456/operations/1870835991191748608
# ReasoningEngine created. Resource name: projects/104435755698/locations/us-central1/reasoningEngines/562186892351635456
# To use this ReasoningEngine in another session:
# reasoning_engine = vertexai.preview.reasoning_engines.ReasoningEngine('projects/104435755698/locations/us-central1/reasoningEngines/562186892351635456')
#
# ✅ AI Agent deployed successfully!
#
# Resource name: projects/104435755698/locations/us-central1/reasoningEngines/562186892351635456
#
# 📝 Save this resource name for querying the agent later!

# %% [markdown]
# ## Cell 12: Query the Deployed AI Agent with Repository Scan

# %%
# Query the deployed AI agent
test_repo = "https://github.com/yourusername/your-repo.git"  # Replace with your repo

print(f"🔍 Scanning repository with AI analysis: {test_repo}\n")

# Query the agent with AI analysis enabled
response = agent_app.query(
    repo_url=test_repo,
    rules="auto",
    include_ai_analysis=True
)

print(response)
# Out:
# 🔍 Scanning repository with AI analysis: https://github.com/yourusername/your-repo.git
#
# ❌ Error during security scan: Failed to clone repository: Cloning into '/tmp/security_scan_ke951aoo'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# ## Cell 13: Query the AI Agent with Security Questions

# %%
# Ask the AI agent security questions
questions = [
    "What are the OWASP Top 10 vulnerabilities?",
    "How can I prevent command injection in Python?",
    "What's the difference between authentication and authorization?"
]

for question in questions:
    print(f"\n{'='*80}")
    print(f"❓ Question: {question}")
    print(f"{'='*80}")
    
    response = agent_app.query(question=question, repo_url=None)
    print(f"\n🤖 Answer:\n{response}")
# Out:
# ================================================================================
# ❓ Question: What are the OWASP Top 10 vulnerabilities?
# ================================================================================
#
# 🤖 Answer:
# Okay, here's a breakdown of the OWASP Top 10 vulnerabilities, presented in a clear and practical manner. Think of this as your quick reference guide for the most critical web application security risks:
#
# **What is the OWASP Top 10?**
#
# The OWASP (Open Web Application Security Project) Top 10 is a regularly updated *awareness document* representing a broad consensus about the most critical security risks to web applications.  It's *not* a standard or a law, but it's widely considered the de facto standard for prioritizing security efforts. It's based on real-world vulnerability data and developer community input.  Knowing these vulnerabilities is a crucial starting point for building and maintaining secure web applications.
#
# **The 2021 OWASP Top 10 (The Most Recent Edition):**
#
# Here's a summary, with explanations and practical mitigations:
#
# 1.  **A01:2021 – Broken Access Control:**
#
#     *   **What it is:**  Failure to properly restrict user access to resources.  This allows users to access data or functionality they shouldn't be able to, like viewing other users' accounts, modifying administrative data, or accessing sensitive files. Access control decisions are not consistently enforced throughout the application.
#
#     *   **Example:**  A URL like `example.com/profile/123` might allow you to view profile number 123. If you change the '123' to '456' and can see another user's profile, that's broken access control.  Another example is having different permissions for admin vs regular user but the code doesn't enforce this properly, or it allows privilege escalation.
#
#     *   **Mitigation:**
#         *   **Implement least privilege principle:**  Grant users only the minimum level of access they need to perform their tasks.
#         *   **Robust access control mechanisms:**  Centralize access control logic and ensure it's consistently applied across the application. Use an Access Control List (ACL) or Role-Based Access Control (RBAC).
#         *   **Properly identify and authenticate users:**  Ensure the application knows who the user is.
#         *   **Deny by default:**  If a user is not explicitly granted access, they should be denied.
#         *   **Thoroughly test access controls:**  Test with different user roles and try to bypass controls.
#
# 2.  **A02:2021 – Cryptographic Failures:** (Formerly "Sensitive Data Exposure")
#
#     *   **What it is:**  Related to improper or insufficient use of cryptography, including failing to protect data at rest and in transit. This means sensitive information like passwords, credit card numbers, personal data, and API keys can be exposed.
#     *   **Example:** Storing passwords in plain text, using weak encryption algorithms, transmitting sensitive data over unencrypted HTTP, or improperly managing encryption keys.
#
#     *   **Mitigation:**
#         *   **Encrypt sensitive data at rest and in transit:**  Use strong, up-to-date cryptographic algorithms (e.g., AES-256 for encryption, SHA-256 or SHA-3 for hashing).
#         *   **Use TLS (HTTPS) for all traffic:**  Enforce HTTPS to encrypt data in transit.
#         *   **Properly manage cryptographic keys:**  Store keys securely (e.g., using a hardware security module (HSM) or key management system (KMS)).  Rotate keys regularly.  Never commit keys into source code.
#         *   **Use vetted cryptographic libraries:** Don't try to implement your own cryptography; rely on well-tested libraries from trusted sources.
#         *   **Avoid storing sensitive data unnecessarily:**  If you don't need the data, don't collect or store it.
#         *   **Implement proper password hashing:** Use a strong, salted hashing algorithm like bcrypt, Argon2, or scrypt.  Never use MD5 or SHA-1.
#
# 3.  **A03:2021 – Injection:**
#
#     *   **What it is:**  Occurs when untrusted data is sent to an interpreter (e.g., SQL database, operating system command line, LDAP) as part of a command or query. The attacker's malicious data tricks the interpreter into executing unintended commands or accessing data without proper authorization.
#     *   **Example:**  SQL Injection, Command Injection, LDAP Injection, OS Command Injection.  If a web form field is used directly in a SQL query without sanitization, an attacker could inject malicious SQL code.
#
#     *   **Mitigation:**
#         *   **Input validation and sanitization:**  Strictly validate and sanitize all user input before using it in commands or queries.  Reject invalid input.
#         *   **Parameterized queries (Prepared Statements):**  Use parameterized queries or prepared statements with variable binding when interacting with databases. This separates the data from the query, preventing the interpreter from executing malicious code.
#         *   **Least privilege:** Run database connections with the minimum privileges necessary.
#         *   **Avoid dynamic construction of commands:**  If possible, avoid constructing commands dynamically. Use pre-defined functions or APIs.
#         *   **Escape special characters:** If you must use user input in a command, properly escape any special characters that could be interpreted as commands.
#         *   **Content Security Policy (CSP):** Use CSP to restrict the sources from which the browser is allowed to load resources, mitigating the risk of script injection.
#
# 4.  **A04:2021 – Insecure Design:**
#
#     *   **What it is:** Represents flaws in the application's architecture and design. Unlike the other items on the list which are typically implementation bugs, Insecure Design focuses on design flaws and missing or ineffective control designs.
#
#     *   **Example:** Lack of threat modeling, insufficient business risk assessment, lacking a secure development lifecycle, or failure to define a proper security architecture.  Assuming that code will always be used as intended is an insecure design flaw.
#
#     *   **Mitigation:**
#         *   **Establish a Secure Development Lifecycle (SDLC):** Integrate security into every phase of development, from requirements gathering to deployment and maintenance.
#         *   **Threat Modeling:** Identify potential threats and vulnerabilities early in the design process.
#         *   **Security Architecture:** Define a clear security architecture that addresses identified risks.
#         *   **Secure Design Patterns:**  Use well-established secure design patterns.
#         *   **Security Reviews:** Conduct regular security reviews of the application design.
#         *   **Implement defense in depth:** Use multiple layers of security controls to protect against attacks.
#         *   **Input validation:** Always validate input before processing it.
#         *   **Authentication and Authorization:** Implement robust authentication and authorization mechanisms.
#         *   **Data validation and encoding:** Validate and encode data to prevent injection attacks.
#         *   **Error handling:** Implement proper error handling to prevent information leakage.
#
# 5.  **A05:2021 – Security Misconfiguration:**
#
#     *   **What it is:**  Occurs when an application or its environment is not properly configured, leaving it vulnerable to attack. This can include using default passwords, having unnecessary features enabled, running outdated software, or not properly configuring security headers.
#
#     *   **Example:**  Using default credentials for database or server, leaving debugging features enabled in production, not patching software vulnerabilities, allowing directory listing on the web server, or not configuring proper security headers like `X-Frame-Options` or `Content-Security-Policy`.
#
#     *   **Mitigation:**
#         *   **Harden the environment:**  Disable unnecessary features, remove default accounts and passwords, and keep software up to date.
#         *   **Automate security configuration:**  Use tools like configuration management software (e.g., Ansible, Chef, Puppet) to automate security configuration and ensure consistency.
#         *   **Regularly review configurations:**  Periodically review security configurations to identify and address any misconfigurations.
#         *   **Secure default configurations:**  Ensure that default configurations are secure.
#         *   **Implement security headers:**  Configure security headers like `X-Frame-Options`, `Content-Security-Policy`, and `Strict-Transport-Security` to protect against various attacks.
#         *   **Patch management:**  Implement a robust patch management process to keep software up to date and address known vulnerabilities.
#
# 6.  **A06:2021 – Vulnerable and Outdated Components:**
#
#     *   **What it is:**  Using outdated or vulnerable third-party components (libraries, frameworks, etc.) that contain known security flaws. Attackers can exploit these vulnerabilities to compromise the application.
#
#     *   **Example:**  Using an outdated version of jQuery with a known XSS vulnerability, or using a vulnerable version of a database driver.
#
#     *   **Mitigation:**
#         *   **Maintain an inventory of all components:**  Track all third-party components used in the application, including their versions.
#         *   **Monitor for vulnerabilities:**  Use tools like software composition analysis (SCA) to monitor for known vulnerabilities in your components.
#         *   **Update components regularly:**  Update components to the latest versions as soon as possible after vulnerabilities are discovered and fixed.  Use automated dependency management tools.
#         *   **Consider using a software bill of materials (SBOM):** SBOMs provide a comprehensive list of all components and their dependencies, making it easier to manage vulnerabilities.
#         *   **Remove unused components:**  Remove any components that are not actively used to reduce the attack surface.
#         *   **Ensure components come from trusted sources:** Use only components from trusted and reputable sources.
#
# 7.  **A07:2021 – Identification and Authentication Failures:** (Formerly "Broken Authentication")
#
#     *   **What it is:**  Issues with identifying and authenticating users. This includes weaknesses in password management, multi-factor authentication, session management, and allowing brute-force attacks.
#
#     *   **Example:**  Weak password policies, allowing default passwords, not implementing multi-factor authentication, using predictable session IDs, not properly invalidating sessions after logout, or being susceptible to brute-force password attacks.
#
#     *   **Mitigation:**
#         *   **Implement multi-factor authentication (MFA):**  Require users to provide multiple factors of authentication (e.g., password + one-time code from a mobile app).
#         *   **Enforce strong password policies:**  Require users to create strong passwords and change them regularly.
#         *   **Implement account lockout:**  Lock out accounts after a certain number of failed login attempts to prevent brute-force attacks.
#         *   **Use secure session management:**  Generate strong, random session IDs and protect them from being stolen or manipulated. Properly invalidate sessions after logout.
#         *   **Rate limiting:** Implement rate limiting on login attempts and other sensitive operations to prevent brute-force attacks.
#         *   **Consider using passwordless authentication:** Explore passwordless authentication methods like biometrics or magic links.
#
# 8.  **A08:2021 – Software and Data Integrity Failures:**
#
#     *   **What it is:** Code and infrastructure did not meet quality expectations, and there is a failure to verify software updates, CI/CD pipelines, and libraries. This can lead to introducing flaws which can lead to data corruption, compromise, or code execution.
#
#     *   **Example:** Allowing updates from untrusted sources without verification, using insecure deserialization methods, or failing to implement data integrity checks.
#
#     *   **Mitigation:**
#         *   **Use digital signatures for software updates:** Verify the authenticity and integrity of software updates before installing them.
#         *   **Implement secure deserialization:** Avoid using insecure deserialization methods. If you must use deserialization, implement strict input validation and filtering. Use a secure serialization format like JSON.
#         *   **Implement data integrity checks:** Use checksums or other integrity checks to verify the integrity of data.
#         *   **Code signing:** Sign your code to ensure that it has not been tampered with.
#         *   **Software Composition Analysis (SCA):** Use SCA tools to identify and address vulnerabilities in third-party libraries.
#         *   **Supply chain security measures:** Implement security measures to protect your software supply chain from attack.
#
# 9.  **A09:2021 – Security Logging and Monitoring Failures:**
#
#     *   **What it is:** Insufficient logging and monitoring of security events, making it difficult to detect and respond to attacks.
#
#     *   **Example:**  Not logging authentication attempts, not monitoring for suspicious activity, not having alerting mechanisms in place, not retaining logs for a sufficient period of time, or not protecting logs from unauthorized access.
#
#     *   **Mitigation:**
#         *   **Implement comprehensive logging:**  Log all relevant security events, including authentication attempts, access control decisions, input validation failures, and errors.
#         *   **Monitor logs for suspicious activity:**  Use a security information and event management (SIEM) system to monitor logs for suspicious patterns and anomalies.
#         *   **Implement alerting mechanisms:**  Set up alerts to notify security personnel when suspicious activity is detected.
#         *   **Retain logs for a sufficient period of time:**  Retain logs for a sufficient period of time to support incident investigation and forensic analysis.
#         *   **Protect logs from unauthorized access:**  Secure logs to prevent unauthorized access or modification.
#         *   **Regularly review logs:**  Regularly review logs to identify and address any security issues.
#
# 10. **A10:2021 – Server-Side Request Forgery (SSRF):**
#
#     *   **What it is:** Occurs when a web application allows an attacker to make requests to arbitrary internal or external resources on the server's behalf.  This can be used to access sensitive internal data, bypass firewalls, or perform other malicious actions.
#
#     *   **Example:**  A web application that allows users to specify a URL to fetch data from. If the application does not properly validate the URL, an attacker could specify an internal URL to access sensitive data or perform actions on the internal network.
#
#     *   **Mitigation:**
#         *   **Validate and sanitize user-supplied URLs:**  Strictly validate and sanitize any URLs provided by users to prevent them from being used to access internal resources.
#         *   **Implement whitelisting:**  Only allow the application to access a predefined list of known and trusted URLs.
#         *   **Disable unnecessary protocols:**  Disable any unnecessary protocols (e.g., file://, gopher://) to prevent attackers from using them to access internal resources.
#         *   **Use network segmentation:**  Segment the network to isolate sensitive resources from the web application server.
#         *   **Implement least privilege:**  Grant the web application server only the minimum privileges necessary to perform its tasks.
#         *   **Use metadata services sparingly:** Avoid having the server reach out to metadata services except when absolutely necessary.
#
#
# **Key Takeaways:**
#
# *   **Prioritization:**  The OWASP Top 10 helps you prioritize your security efforts. Address these vulnerabilities first.
# *   **Developer Education:**  Train developers on these vulnerabilities and how to avoid them.
# *   **Regular Updates:**  Keep an eye on the OWASP website (owasp.org) for updates to the Top 10. Security threats are constantly evolving.
# *   **Comprehensive Approach:**  The OWASP Top 10 is a good starting point, but it's not a complete security solution. Implement a comprehensive security program that includes risk assessments, security testing, and ongoing monitoring.
#
# By understanding and addressing these top vulnerabilities, you can significantly improve the security of your web applications.
#
#
# ================================================================================
# ❓ Question: How can I prevent command injection in Python?
# ================================================================================
#
# 🤖 Answer:
# Okay, here's a breakdown of how to prevent command injection vulnerabilities in Python, keeping it practical and easy to understand:
#
# **Understanding Command Injection**
#
# Command injection occurs when an attacker can inject arbitrary commands into a system through a vulnerable application.  This usually happens when the application executes system commands based on user-supplied input without proper sanitization or validation.  In Python, this often involves using functions like `os.system`, `subprocess.run`, `subprocess.Popen`, or similar methods to execute shell commands.
#
# **The Golden Rule:  Never Directly Use User Input in System Commands**
#
# The absolute best way to prevent command injection is to *avoid* using user-supplied data directly in system commands.  Consider alternative approaches that don't require executing shell commands in the first place. If that's not possible, follow the guidance below.
#
# **Practical Prevention Techniques**
#
# 1. **Use `subprocess.run` with `shell=False` and a List of Arguments (Recommended):**
#
#    This is the most secure and recommended approach.  By setting `shell=False`, you force `subprocess.run` to execute the command directly, treating each element in the argument list as a distinct argument to the command.  This prevents shell interpretation of special characters.
#
#    ```python
#    import subprocess
#
#    def process_file(filename):
#        # Input validation is still crucial (see below)
#        if not validate_filename(filename):
#            return "Invalid filename"
#
#        # Define the command and its arguments as a list
#        command = ['ls', '-l', filename]  # Example: listing the file details.
#
#        try:
#            result = subprocess.run(command, capture_output=True, text=True, check=True, shell=False)  # shell=False is key!
#            print("Command output:", result.stdout)
#            return result.stdout
#        except subprocess.CalledProcessError as e:
#            print("Error executing command:", e)
#            return f"Error: {e.stderr}"
#
#    def validate_filename(filename):
#         # Add your specific filename validation logic here.
#         # Examples:
#         # - Check for allowed characters (e.g., alphanumeric, underscores, dots)
#         # - Check the filename extension
#         # - Check the filename length
#         # - Use a whitelist of allowed filenames, if possible
#         # IMPORTANT:  This is a placeholder.  Implement real validation!
#         if ".." in filename or ";" in filename or "&" in filename: # Example malicious characters
#             return False
#         return True
#
#    # Example usage (with user input - this is where validation matters!)
#    user_provided_filename = input("Enter filename: ")
#    output = process_file(user_provided_filename)
#    print(output)
#    ```
#
#    **Explanation:**
#
#    *   `shell=False`:  Critical!  Disables shell interpretation, preventing attackers from injecting commands using shell metacharacters.
#    *   List of arguments:  The command and its arguments are passed as a list.  This avoids the shell's interpretation of special characters within the arguments.
#    *   `capture_output=True`:  Captures the standard output and standard error streams of the command.
#    *   `text=True`:  Decodes the output as text.
#    *   `check=True`:  Raises a `subprocess.CalledProcessError` if the command returns a non-zero exit code (indicating an error).  Good for error handling.
#    *   **Crucial: Input Validation:**  Even with `shell=False`, you still need to validate the `filename` input to ensure it's what you expect.  Malicious filenames can still cause unexpected behavior (e.g., overwriting files, triggering bugs in the called program).  See point #4 below for more on validation.
#
# 2. **Avoid `os.system` and `subprocess.call` with `shell=True`:**
#
#    These functions are highly vulnerable to command injection if user input is involved.  They execute the command through the system shell, allowing attackers to inject commands using shell metacharacters (e.g., `;`, `|`, `&`, `>`, `<`, `$(...)`).  **Never use these with untrusted input!**
#
# 3. **Consider Alternatives to Shell Commands:**
#
#    Before resorting to running shell commands, ask yourself if there's a Python library or built-in function that can achieve the same result.  For example:
#
#    *   Instead of `ls -l`, use `os.stat` or `os.listdir`.
#    *   Instead of `mkdir`, use `os.makedirs`.
#    *   Instead of command-line image processing tools, use libraries like Pillow.
#    *   Instead of command-line archive utilities, use the `zipfile` or `tarfile` modules.
#
#    This avoids the need for shell commands altogether, eliminating the risk of command injection.
#
# 4. **Input Validation and Sanitization (Essential, Even with `shell=False`):**
#
#    Even when using `subprocess.run` with `shell=False`, you *must* validate and sanitize user-provided input before using it in any command.  This is crucial because:
#
#    *   A malicious filename (even if not directly executing commands) can still cause unexpected behavior or vulnerabilities in the program being executed.
#    *   `shell=False` prevents *shell* injection, but doesn't prevent exploitation of vulnerabilities in the command itself (e.g. passing an overly long string, or a string with unusual characters that causes a buffer overflow, or similar vulnerabilities in the external command).
#
#    Here's what input validation should include:
#
#    *   **Whitelist Allowed Characters:** Allow only specific characters (e.g., alphanumeric, underscores, hyphens, dots) and reject anything else. Regular expressions are helpful here.
#    *   **Check Filename Extensions:** Verify that the filename has an expected extension (e.g., `.txt`, `.jpg`, `.pdf`).
#    *   **Validate Path Traversal:** Prevent path traversal attacks (e.g., `../../../../etc/passwd`).  Reject filenames containing `..`.  Use `os.path.abspath` and `os.path.normpath` to normalize paths and ensure they are within the expected directory.
#    *   **Limit Input Length:** Restrict the length of the input to prevent buffer overflows or other issues.
#    *   **Use a Whitelist of Values (If Possible):** If you have a limited set of acceptable values (e.g., specific usernames or option names), use a whitelist (a pre-approved list) to ensure only valid values are used.
#
#    Example of input validation using regular expressions:
#
#    ```python
#    import re
#
#    def is_valid_filename(filename):
#        pattern = r"^[a-zA-Z0-9._-]+$"  # Allows letters, numbers, dots, underscores, and hyphens
#        if re.match(pattern, filename):
#            return True
#        else:
#            return False
#
#    user_input = input("Enter a filename: ")
#    if is_valid_filename(user_input):
#        print("Filename is valid.")
#        # ... Use the filename (carefully!) ...
#    else:
#        print("Invalid filename!")
#    ```
#
# 5. **Least Privilege:**
#
#    Run the Python script (and any commands it executes) with the minimum necessary privileges.  If possible, create a dedicated user account with limited permissions for the application.  This limits the damage an attacker can do if they manage to inject a command.
#
# 6. **Output Sanitization:**
#
#    Even if you've prevented command injection, sanitize the output of the commands you run before displaying it to the user or using it in further processing.  This prevents other vulnerabilities, such as cross-site scripting (XSS).
#
# **Example Scenario: Converting an Image**
#
# Let's say you want to allow users to convert an image to a different format using ImageMagick's `convert` command.  Here's how to do it safely:
#
# ```python
# import subprocess
# import os
# import re
#
# def convert_image(input_file, output_file, target_format):
#     """Converts an image using ImageMagick's 'convert' command securely."""
#
#     # 1. Input Validation
#     if not is_valid_image_filename(input_file):
#         return "Invalid input filename."
#     if not is_valid_image_filename(output_file):
#         return "Invalid output filename."
#     if target_format not in ["jpg", "png", "gif"]:  # Whitelist allowed formats
#         return "Invalid target format."
#
#     # 2.  Create a secure output path
#     # Ensure the output file is within an expected directory.  Avoid allowing the user
#     # to write arbitrary files to arbitrary locations.
#     output_directory = "converted_images"
#     os.makedirs(output_directory, exist_ok=True)  # Create the directory if it doesn't exist
#     secure_output_path = os.path.join(output_directory, output_file)
#
#     # 3. Build the command with shell=False
#     command = ['convert', input_file, secure_output_path]  # No shell interpretation!
#
#     # 4. Execute the command
#     try:
#         result = subprocess.run(command, capture_output=True, text=True, check=True, shell=False)
#         return "Image conversion successful.  Output: " + result.stdout
#     except subprocess.CalledProcessError as e:
#         return f"Image conversion failed: {e.stderr}"
#
#
# def is_valid_image_filename(filename):
#     """Validates that the filename is an allowed image format and safe."""
#     pattern = r"^[a-zA-Z0-9._-]+\.(jpg|jpeg|png|gif)$"  # Allowed image extensions
#     if re.match(pattern, filename):
#         return True
#     else:
#         return False
#
# # Example usage (with careful consideration of user input)
# user_input_file = input("Enter the input image filename: ")
# user_output_file = input("Enter the desired output image filename (e.g., output.jpg): ")
# user_target_format = input("Enter the desired format (jpg, png, gif): ")
#
# result = convert_image(user_input_file, user_output_file, user_target_format)
# print(result)
# ```
#
# **Key Takeaways**
#
# *   **`shell=False` with `subprocess.run` is your primary defense.**
# *   **Input validation is essential, regardless of whether you use `shell=False`.**
# *   **Minimize the use of shell commands whenever possible.**
# *   **Apply the principle of least privilege.**
# *   **Sanitize output to prevent other vulnerabilities.**
# By following these guidelines, you can significantly reduce the risk of command injection vulnerabilities in your Python applications. Remember that security is an ongoing process; always review and update your security practices as needed.
#
#
# ================================================================================
# ❓ Question: What's the difference between authentication and authorization?
# ================================================================================
#
# 🤖 Answer:
# Okay, here's a breakdown of the difference between authentication and authorization, explained from a security expert's perspective:
#
# **Authentication: Proving Who You Are**
#
# *   **Definition:** Authentication is the process of verifying the identity of a user, device, or system. It answers the question: "Are you *really* who you claim to be?"
#
# *   **Analogy:** Think of it like showing your driver's license to a security guard at a gated community entrance. Your driver's license proves *who* you are.
#
# *   **How it works:** This typically involves providing credentials that the system can verify. Common methods include:
#
#     *   **Passwords:** Entering a username and password.
#     *   **Multi-Factor Authentication (MFA):**  Requiring multiple factors (e.g., password *and* a code from a mobile app) to confirm identity. This adds an extra layer of security.
#     *   **Biometrics:** Using fingerprints, facial recognition, or other unique biological traits.
#     *   **Digital Certificates:** Using cryptographic certificates to verify identity.
#     *   **Token-Based Authentication (OAuth, JWT):**  Exchanging credentials for a temporary token that represents the user's identity.
#     *   **IP Address filtering**: Accepting traffic from predefined IP Addresses.
#
# *   **Failure:** If authentication fails (wrong password, invalid certificate, etc.), the system denies access. You don't even get a chance to see what resources are available.
#
# **Authorization: What You're Allowed to Do**
#
# *   **Definition:** Authorization is the process of determining what a *authenticated* user, device, or system is permitted to access or do. It answers the question: "Now that we know who you are, what are you *allowed* to do?"
#
# *   **Analogy:** After the security guard verifies your driver's license (authentication), they check their list to see if you're on the visitor list for a particular resident (authorization). If you're on the list, they let you in to visit *that* specific resident.
#
# *   **How it works:** Once authenticated, the system checks the user's permissions or role. This is often managed through:
#
#     *   **Access Control Lists (ACLs):**  Defining specific permissions for each user or group on individual resources (e.g., file permissions).
#     *   **Role-Based Access Control (RBAC):** Assigning users to roles (e.g., "administrator", "editor", "viewer"), and then granting permissions to those roles.
#     *   **Attribute-Based Access Control (ABAC):** Using attributes of the user, the resource, and the environment to make authorization decisions (e.g., "only doctors can access patient records during business hours").
#     *   **Capabilities:** Holding a secret "key" to access a certain resource.
#
# *   **Failure:**  If authorization fails (e.g., you don't have permission to access a specific file, or perform a certain action), the system denies access to *that* specific resource or action, even though you're a valid user.  You might be able to access *other* resources you *are* authorized for.
#
# **Key Differences Summarized:**
#
# | Feature        | Authentication                                     | Authorization                                       |
# |----------------|----------------------------------------------------|-------------------------------------------------------|
# | **Purpose**     | Verifies identity ("Who are you?")             | Determines access rights ("What can you do?")       |
# | **Timing**      | Occurs *before* authorization                    | Occurs *after* successful authentication            |
# | **Outcome**     | Grant or deny access *entirely*                  | Grant or deny access to *specific resources/actions* |
# | **Example**    | Entering username/password correctly             | Being allowed to edit a document vs. only view it   |
# | **Common Tech**| Passwords, MFA, Biometrics, Certificates, OAuth   | ACLs, RBAC, ABAC, Capabilities                   |
#
# **Why This Distinction Matters for Security:**
#
# *   **Comprehensive Security:** You need *both* authentication and authorization for a secure system. Good authentication without proper authorization is like giving everyone a key to the front door, but not restricting what they can do inside. Good authorization without proper authentication is like letting anyone walk in and claim to be someone else.
# *   **Least Privilege:** Proper authorization is crucial for the principle of least privilege – giving users only the access they absolutely need to perform their job. This minimizes the potential damage if a user's account is compromised.
# *   **Defense in Depth:**  Authentication and authorization are core layers in a defense-in-depth security strategy.  If one layer fails, the other may still provide protection.
# *   **Compliance:** Many security compliance standards (e.g., HIPAA, PCI DSS) require strong authentication and authorization controls to protect sensitive data.
#
# In conclusion, authentication confirms identity, while authorization dictates what an authenticated user can do. Both are crucial components of a robust security architecture.

# %% [markdown]
# ## Cell 14: Compare Scans With and Without AI Analysis

# %%
import time

test_repo = "https://github.com/1mr0-tech/k3s-suite.git"  # Replace

print("📊 Comparing scan performance with and without AI analysis\n")

# Without AI analysis
print("1️⃣ Running scan WITHOUT AI analysis...")
start = time.time()
response_no_ai = agent_app.query(
    repo_url=test_repo,
    include_ai_analysis=False
)
time_no_ai = time.time() - start
print(f"   ⏱️  Time: {time_no_ai:.2f} seconds\n")

# With AI analysis
print("2️⃣ Running scan WITH AI analysis...")
start = time.time()
response_with_ai = agent_app.query(
    repo_url=test_repo,
    include_ai_analysis=True
)
time_with_ai = time.time() - start
print(f"   ⏱️  Time: {time_with_ai:.2f} seconds\n")

print(f"\n📈 Results:")
print(f"   Without AI: {time_no_ai:.2f}s")
print(f"   With AI: {time_with_ai:.2f}s")
print(f"   AI adds: {time_with_ai - time_no_ai:.2f}s of intelligent analysis")
# Out:
# 📊 Comparing scan performance with and without AI analysis
#
# 1️⃣ Running scan WITHOUT AI analysis...
#    ⏱️  Time: 115.13 seconds
#
# 2️⃣ Running scan WITH AI analysis...
#    ⏱️  Time: 166.36 seconds
#
#
# 📈 Results:
#    Without AI: 115.13s
#    With AI: 166.36s
#    AI adds: 51.22s of intelligent analysis

# %% [markdown]
# ## Cell 15: List All Deployed Agents

# %%
# List all reasoning engines in your project
agents = reasoning_engines.ReasoningEngine.list()

print("📋 Deployed AI Agents:\n")
for agent in agents:
    print(f"Display Name: {agent.display_name}")
    print(f"Resource Name: {agent.resource_name}")
    print(f"Create Time: {agent.create_time}")
    print("-" * 80)
# Out:
# 📋 Deployed AI Agents:
#
# Display Name: ai-security-scanner-agent
# Resource Name: projects/104435755698/locations/us-central1/reasoningEngines/562186892351635456
# Create Time: 2025-12-19 18:52:56.542019+00:00
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Cell 16: Interactive AI Security Assistant

# %%
# Interactive mode - ask multiple questions
print("🤖 AI Security Assistant Ready!")
print("Ask questions about security vulnerabilities...\n")

# Example questions you can ask
example_questions = [
    "What is XSS and how do I prevent it?",
    "Explain CSRF attacks",
    "What are the best practices for password storage?",
    "How does HTTPS work?",
    "What is the principle of least privilege?"
]

# Ask a custom question (modify as needed)
your_question = "What is the difference between SQL injection and command injection?"

print(f"❓ Your Question: {your_question}\n")
answer = agent_app.query(question=your_question, repo_url=None)
print(f"🤖 AI Answer:\n{answer}")

# %% [markdown]
# ## Cell 17: Clean Up - Delete Agent (Optional)
#
# ⚠️ Only run this if you want to delete the deployed agent.

# %%
# Delete the agent
print("🗑️ Deleting AI agent...")
agent_app.delete()
print("✅ AI agent deleted successfully!")
# Out:
# 🗑️ Deleting AI agent...
# Deleting ReasoningEngine : projects/104435755698/locations/us-central1/reasoningEngines/562186892351635456
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:75, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      74 try:
# ---> 75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
#
# File /opt/conda/lib/python3.10/site-packages/grpc/_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)
#     274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
#     280         credentials=credentials,
#     281         wait_for_ready=wait_for_ready,
#     282         compression=compression,
#     283     )
#     284     return response
#
# File /opt/conda/lib/python3.10/site-packages/grpc/_interceptor.py:331, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     328 call = self._interceptor.intercept_unary_unary(
#     329     continuation, client_call_details, request
#     330 )
# --> 331 return call.result(), call
#
# File /opt/conda/lib/python3.10/site-packages/grpc/_channel.py:438, in _InactiveRpcError.result(self, timeout)
#     437 """See grpc.Future.result."""
# --> 438 raise self
#
# File /opt/conda/lib/python3.10/site-packages/grpc/_interceptor.py:314, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     313 try:
# --> 314     response, call = self._thunk(new_method).with_call(
#     315         request,
#     316         timeout=new_timeout,
#     317         metadata=new_metadata,
#     318         credentials=new_credentials,
#     319         wait_for_ready=new_wait_for_ready,
#     320         compression=new_compression,
#     321     )
#     322     return _UnaryOutcome(response, call)
#
# File /opt/conda/lib/python3.10/site-packages/grpc/_channel.py:1180, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1177 state, call = self._blocking(
#    1178     request, timeout, metadata, credentials, wait_for_ready, compression
#    1179 )
# -> 1180 return _end_unary_response_blocking(state, call, True, None)
#
# File /opt/conda/lib/python3.10/site-packages/grpc/_channel.py:996, in _end_unary_response_blocking(state, call, with_call, deadline)
#     995     return state.response
# --> 996 raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.NOT_FOUND
# 	details = "The ReasoningEngine does not exist."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:74.125.69.95:443 {grpc_status:5, grpc_message:"The ReasoningEngine does not exist."}"
# >
#
# The above exception was the direct cause of the following exception:
#
# NotFound                                  Traceback (most recent call last)
# Cell In[33], line 3
#       1 # Delete the agent
#       2 print("🗑️ Deleting AI agent...")
# ----> 3 agent_app.delete()
#       4 print("✅ AI agent deleted successfully!")
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/aiplatform/base.py:862, in optional_sync.<locals>.optional_run_in_thread.<locals>.wrapper(*args, **kwargs)
#     860     if self:
#     861         VertexAiResourceNounWithFutureManager.wait(self)
# --> 862     return method(*args, **kwargs)
#     864 # callbacks to call within the Future (in same Thread)
#     865 internal_callbacks = []
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/aiplatform/base.py:1370, in VertexAiResourceNounWithFutureManager.delete(self, sync)
#    1359 @optional_sync()
#    1360 def delete(self, sync: bool = True) -> None:
#    1361     """Deletes this Vertex AI resource. WARNING: This deletion is
#    1362     permanent.
#    1363
#    (...)
#    1368             be immediately returned and synced when the Future has completed.
#    1369     """
# -> 1370     self._delete()
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/aiplatform/base.py:1201, in _VertexAiResourceNounPlus._delete(self)
#    1199 """Deletes this Vertex AI resource. WARNING: This deletion is permanent."""
#    1200 _LOGGER.log_action_start_against_resource("Deleting", "", self)
# -> 1201 possible_lro = getattr(self.api_client, self._delete_method)(
#    1202     name=self.resource_name
#    1203 )
#    1205 if possible_lro:
#    1206     _LOGGER.log_action_completed_against_resource("deleted.", "", self)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/aiplatform_v1beta1/services/reasoning_engine_service/client.py:1483, in ReasoningEngineServiceClient.delete_reasoning_engine(self, request, name, retry, timeout, metadata)
#    1480 self._validate_universe_domain()
#    1482 # Send the request.
# -> 1483 response = rpc(
#    1484     request,
#    1485     retry=retry,
#    1486     timeout=timeout,
#    1487     metadata=metadata,
#    1488 )
#    1490 # Wrap the response in an operation future.
#    1491 response = gac_operation.from_gapic(
#    1492     response,
#    1493     self._transport.operations_client,
#    1494     empty_pb2.Empty,
#    1495     metadata_type=gca_operation.DeleteOperationMetadata,
#    1496 )
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# NotFound: 404 The ReasoningEngine does not exist.

# %% [markdown]
# ##SUMMARY

# %%
print("""
╔══════════════════════════════════════════════════════════════════════╗
║            🤖 AI-POWERED SECURITY AGENT WORKSHOP COMPLETE! 🎉       ║
╚══════════════════════════════════════════════════════════════════════╝

✅ What We Accomplished:
   • Created an AI-powered Security Scanner Agent
   • Integrated Gemini API for intelligent analysis
   • Tested with vulnerable sample code
   • Deployed to Vertex AI
   • Scanned GitHub repositories with AI insights
   • Generated AI-powered executive summaries
   • Built an interactive security Q&A system

🤖 AI Features Demonstrated:
   • Vulnerability analysis and explanation
   • Executive summaries for management
   • Code fix suggestions
   • Risk assessment and prioritization
   • Natural language Q&A about security

📚 Next Steps:
   1. Integrate with your CI/CD pipeline
   2. Customize AI prompts for your organization
   3. Add more AI features (fix generation, code review)
   4. Set up automated scanning with AI reports
   5. Create dashboards with AI-generated insights

🔧 Key API Endpoints:
   • Scan with AI: agent.query(repo_url="...", include_ai_analysis=True)
   • Ask question: agent.query(question="...", repo_url=None)
   • Quick scan: agent.query(repo_url="...", include_ai_analysis=False)

💡 AI Use Cases:
   • Developer education on vulnerabilities
   • Management reporting with executive summaries
   • Code review assistance
   • Security training and awareness
   • Automated remediation suggestions

📖 Resources:
   • Gemini API: https://ai.google.dev/
   • Semgrep: https://semgrep.dev/docs
   • Vertex AI: https://cloud.google.com/vertex-ai/docs

🎯 Why This is AI-Powered:
   • Gemini analyzes vulnerabilities contextually
   • Generates human-readable explanations
   • Prioritizes issues based on risk
   • Suggests specific code fixes
   • Answers follow-up questions naturally

Thank you for participating! 🙏
This agent combines the power of static analysis with AI intelligence!
""")
